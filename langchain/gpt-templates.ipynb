# %%
import configparser
config = configparser.ConfigParser()
config.read('../training/secrets.ini')
import os
import openai
os.environ.update({'OPENAI_API_KEY': config['OPENAI']['OPENAI_API_KEY']})
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
system_prompt_template= """
You are an expert on sparql and wikibase. I have a private wikibase where the p and q items are completely unknown to you. 

If you are asked to provide a "query template json" for a user question, you should respond with a json object with these keys and values:
* 'query_template': a python-style template string. the query template should not use 'rdfs:label' to help you find items. Instead, just use a placeholder tag for each p and q item you need. Each tag should begin with "p-" or "q-" depending on whether you think you need a p or a q item
* 'vocabulary': a list of objects, one for each p or q item you need for a sparql query, each item should have these components:
** 'item_tag': a placeholder string that you make up
** 'item_label_quesses': a list of up to three different strings that you think might be used as the label for that p or q item
Remember: you do not know the actual q or p items in my wikibase, so make sure to list ALL p and q items in the 'vocabulary' section of the json.

You may assume the following prefixes:
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX p: <http://www.wikidata.org/prop/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>

Respond only with the json. Do not include any comments or explanations.

"""

# %%
example1_human = """
generate a query template json for the question "Does malin 1 have a right ascension lower than 15.1398?"
"""

# %%
example1_ai = """
{{
  "query_template": "SELECT ?result WHERE {{ wd:q-Malin1 wdt:p-RightAscension ?right_ascension . FILTER(?right_ascension < 15.1398) BIND(xsd:boolean(?right_ascension < 15.1398) as ?result) }}",
  "vocabulary": [
    {{
      "item_tag": "q-Malin1",
      "item_label_quesses": ["Malin 1", "Malin-1", "Malin1"]
    }},
    {{
      "item_tag": "p-RightAscension",
      "item_label_quesses": ["Right ascension", "right_ascension", "RA"]
    }}
  ]
}}
"""

# %%
example2_human = """
How many children did J.S. Bach have?
"""

# %%
example2_ai = """
{{
  "query_template": "w
  "vocabulary": [
    {{
      "item_tag": "q-JSBach",
      "item_label_quesses": ["Johann Sebastian Bach", "Bach, Johann Sebastian", "J.S. Bach"]
    }},
    {{
      "item_tag": "p-Child",
      "item_label_quesses": ["Child", "Offspring", "Progeny"]
    }}
  ]
}}
"""

# %%
from langchain.prompts import (
    ChatPromptTemplate,
    PromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)

# %%
template=system_prompt_template
system_message_prompt = SystemMessagePromptTemplate.from_template(template)

example_human_1 = HumanMessagePromptTemplate.from_template(example1_human)
example_ai_1 = AIMessagePromptTemplate.from_template(example1_ai)
example_human_2 = HumanMessagePromptTemplate.from_template(example2_human)
example_ai_2 = AIMessagePromptTemplate.from_template(example2_ai)

human_template="Please generate query template json for this question: {text}"
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

# %%
from langchain.chat_models import ChatOpenAI
chat = ChatOpenAI(temperature=0)

# %%
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, example_human_1, example_ai_1, example_human_2, example_ai_2, human_message_prompt])

# %%
from langchain import PromptTemplate, LLMChain
chain = LLMChain(llm=chat, prompt=chat_prompt)
result = chain.run('Which is the Basketball-Reference.com NBA player ID of Hakeem Olajuwon?')
print(result)
# Out:
# WARNING:/opt/homebrew/anaconda3/envs/conda210/lib/python3.9/site-packages/langchain/chat_models/openai.py:Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')).
# {
#   "query_template": "SELECT ?player_id WHERE { wd:q-HakeemOlajuwon wdt:p-BasketballReferencecomNBAPlayerID ?player_id . }",
#   "vocabulary": [
#     {
#       "item_tag": "q-HakeemOlajuwon",
#       "item_label_quesses": ["Hakeem Olajuwon", "Olajuwon, Hakeem"]
#     },
#     {
#       "item_tag": "p-BasketballReferencecomNBAPlayerID",
#       "item_label_quesses": ["Basketball-Reference.com NBA player ID", "BasketballReference.com NBA Player ID", "Basketball-Reference NBA player ID"]
#     }
#   ]
# }

# %%
import json

# %%
query_template = json.loads(result)

# %%
from typing import Any, Dict, List, Optional, Union

def get_nested_value(nested_dict: Dict[str, Any], path: List[str]) -> Optional[Any]:
    """
    Retrieves a value from a nested dictionary structure using a list of keys as a path.

    :param nested_dict: The nested dictionary structure to traverse.
    :param path: A list of strings representing the keys to traverse in order to access the desired value.
    :return: The value at the end of the path if it exists, or None if any key in the path is not found.
    """
    current = nested_dict
    for key in path:
        if not isinstance(current, dict) or key not in current:
            return None
        current = current[key]
    return current

# %%
import requests
from typing import Optional

def vocab_lookup(search: str, entity_type: str = "item",
                 item_tag: str = None, 
                 srqiprofile: str = "classic") -> Optional[str]:
    
    if item_tag is not None:
        if item_tag.startswith("q-"):
            entity_type = "item"
        elif item_tag.startswith("p-"):
            entity_type = "property"   
    
    if entity_type == "item":
        srnamespace = 0
    elif entity_type == "property":
        srnamespace = 120
    else:
        raise ValueError("entity_type must be either 'property' or 'item'")      
        
    url = "https://www.wikidata.org/w/api.php"
    params = {
        "action": "query",
        "list": "search",
        "srsearch": search,
        "srnamespace": srnamespace,
        "srlimit": 5,
        "srqiprofile": srqiprofile,
        "format": "json"
    }
    headers = {'Accept': 'application/json'}

    response = requests.get(url, headers=headers, params=params)
        
    if response.status_code == 200:
        results = get_nested_value(response.json(), ['query', 'search'])
        if results and len(results) > 0:
            title = results[0]['title']
            # properties are returned with a prefix 'property:'
            return results[0]['title'].split(':')[-1]
        else:
            print(f"No {entity_type} found for '{search}'")
            return ""
    else:
        print(f"Request failed with status code {response.status_code}")
        return ""

# %%
def resolve_query_template(t):
    vocab_items = [(v["item_tag"], v["item_label_quesses"]) for v in t["vocabulary"]]
    # since this is not a proper template, we use "replace" below
    # so we need to be careful that some tags may be prefixes of others
    # sorting them by tag length avoids that
    vocab_items = sorted(vocab_items, key=lambda x: x[0], reverse=True)
    resolved_vocabulary = {item_tag: vocab_lookup(item_label_quesses[0], item_tag=item_tag) for item_tag, item_label_quesses in vocab_items}
    query = t['query_template']
    for item_tag, item_id in resolved_vocabulary.items():
        query = query.replace(item_tag, item_id)
    result = query
    return result

# %%
resolve_query_template(query_template)
# Out:
# 'SELECT ?player_id WHERE { wd:Q273256 wdt:P2685 ?player_id . }'

# %%
def translator(question):
    llm_result = chain.run(question)
    try:
        query_template = json.loads(llm_result)
    except Exception:
        query_template = "" 
    query = resolve_query_template(query_template)
    return query

# %%
translator("The Juventus F.C. has what number of participating teams?")
# Out:
# 'SELECT (COUNT(?team) as ?result) WHERE { wd:Q1422 wdt:P1923 ?team }'

# %% [markdown]
# # Validation testing for Natural Language Question to SPARQL Query

# %% [markdown]
# Create a df for the lcquad queries

# %%
import pandas as pd

# %%
lcquad_path = "../../lcquad2.0.train.json"

# %%
# !ls -l {lcquad_path}
# Out:
# -rw-r--r--@ 1 i857913  staff  26561843 Feb  6 16:58 ../../lcquad2.0.train.json

# %%
lcquad_df = pd.read_json(lcquad_path)

# %%
len(lcquad_df)
# Out:
# 24180

# %% [markdown]
# Make a sparql runner

# %%
from wikibaseintegrator import wbi_helpers
from wikibaseintegrator.wbi_config import config as wbi_config
import logging

# %%
wbi_config['USER_AGENT'] = 'AskwikiBot/1.0 (https://www.wikidata.org/wiki/User:What_Tottles_Meant)'
wbi_config['BACKOFF_MAX_TRIES'] = 1

# %%
from requests.exceptions import HTTPError

def run_sparql(query):
    try:
        results = wbi_helpers.execute_sparql_query(query)
    except HTTPError as he:
        logging.error(f'HTTPError {he}')
        print(f"failed query {query}")
        return None
    # print(results)
    if 'boolean' in results:
        return pd.DataFrame([{'Boolean': results['boolean'] }])
    jsonResult = [dict([(k, b[k]['value']) for k in b]) for b in results['results']['bindings']]
    df = pd.DataFrame.from_dict(jsonResult)
    return df

# %%
import requests
from typing import List, Dict, Any

def run_sparql(query: str) -> List[Dict[str, Any]]:
    url = 'https://query.wikidata.org/sparql'
    headers = {
        'Accept': 'application/json',
        'User-Agent': 'AskwikiBot/1.0 (https://www.wikidata.org/wiki/User:What_Tottles_Meant)'
    }

    response = requests.get(url, headers=headers, params={'query': query, 'format': 'json'})

    if response.status_code == 200:
        results = response.json().get('results', {}).get('bindings', [])
        return results
    else:
        print(f"Request failed with status code {response.status_code}")
        return None

# %%
import time
def validate_queries(qs):
    validation_results = []
    count = 0
    for q in qs:
        print(count)
        if not 'limit' in q.lower():
            q += ' limit 100'
        print(q)
        df = run_sparql(q)
        result_count = 0
        if df is None:
            run_result = 'Fail'
            print(f"Failed query number {count}")
        else:
            run_result = 'Pass'
            result_count = len(df)
        validation_results.append((run_result, result_count))
        count += 1
        time.sleep(2)
    return validation_results

# %%
v = validate_queries(lcquad_df['sparql_wikidata'].loc[0:5])
# Out:
# 0
#  select distinct ?obj where { wd:Q188920 wdt:P2813 ?obj . ?obj wdt:P31 wd:Q1002697 }  limit 100
# 1
# SELECT ?answer WHERE { wd:Q169794 wdt:P26 ?X . ?X wdt:P22 ?answer} limit 100
# 2
# ASK WHERE { wd:Q174843 wdt:P106 wd:Q1804811 . wd:Q174843 wdt:P106 wd:Q33231 } limit 100
# Request failed with status code 400
# Failed query number 2
# 3
# SELECT ?answer WHERE { wd:Q675176 wdt:P515 ?X . ?X wdt:P156 ?answer} limit 100
# 4
# select distinct ?answer where { wd:Q32491 wdt:P3362 ?answer} limit 100
# 5
# SELECT DISTINCT ?sbj ?sbj_label WHERE { ?sbj wdt:P31 wd:Q134041 . ?sbj rdfs:label ?sbj_label . FILTER(STRSTARTS(lcase(?sbj_label), 'p')) . FILTER (lang(?sbj_label) = 'en') } LIMIT 25

# %%
v_df = pd.DataFrame(v)

# %%
len(v_df[v_df[0] == 'Pass'])
# Out:
# 5

# %% [markdown]
#
# ## Validate the queries

# %%
def generate_sparql(question):
    sparql = translator(f"translate English to SPARQL: {question}")
    logging.info(f'sparql {sparql}')
    return sparql

# %%
generate_sparql('What are the most common types of liver infection')
# Out:
# "SELECT ?type (COUNT(?disease) AS ?count) WHERE { ?disease wdt:P31 ?type . ?disease rdfs:label ?label . FILTER(LANG(?label) = 'en') FILTER(CONTAINS(LCASE(?label), 'liver infection')) } GROUP BY ?type ORDER BY DESC(?count) LIMIT 10"

# %%
def generate_lots_of_sparql(l):
    result = []
    count = 0
    for s in l:
        # if count % 10 == 0:
        print(s) 
        print(count)
        try:
            sp = generate_sparql(s)
        except Exception:
            sp = ""
        result.append(sp)
        count += 1
    print(count)
    return result

# %%
# %%time
queries = generate_lots_of_sparql(lcquad_df['question'].loc[50:549])
# Out:
# Which country has highest individual tax rate?
# 0
# When did James Thomas Farrell receive the St. Louis Literary Award?
# 1
# When was Pablo Picasso's partnership with Fernade Oliver over?
# 2
# What is the product with the lowest consumption rate per capita whose has part is paraffin wax?
# 3
# No item found for 'bd:serviceParam'
# What are the coordinates for the geographic center of Michigan, as determined by the center of gravity of the surface?
# 4
# Is the life expectancy of Indonesia 55.3528?
# 5
# When did Emmerson Mnangagwa begin going to the University of Zambia?
# 6
# What kind of career does Grigori Kozintsev have in the screenwriting field?
# 7
# what is hypothetical protein ecia139-4120 habitat of found in species?
# 8
# What sovereign state replaced the Kingdom of Great Britain?
# 9
# Of the century breaks of the Colm Gilcreest equal less than 9.6?
# 10
# In which country the Golden Horde used to live ?
# 11
# Located in the Central District, what is the county seat whose twin cities include Feodosiya?
# 12
# No item found for ''
# When did Nicaragua count a population of 3.87732e+06 inhabitants?
# 13
# What does emigration mean?
# 14
# Which is the meta-organization that is regulated by the football association?
# 15
# When was the spouse divorced Nero in 9-6-68
# 16
# n/a
# 17
# Former champion Francisco Alarcon gave what award to Art Spiegelaman?
# 18
# No property found for 'Former champion'
# Are there more than 0 survivors of the Charkhi Dadri mid-air collision
# 19
# When did Secretariat receive the Triple Crown Trophy?
# 20
# Which borders of borders of Riverside have a start date of 1984-0-0?
# 21
# Which is the facility of the defensive wall?
# 22
# What is  in the IHO Hydrographic Dictionary (S-32) Number of lighthouse ?
# 23
# Which is the fictional analog of Hippocampus?
# 24
# What is a cause of death that begins with the letter "p" and can be found on a CT scan?
# 25
# What is established by Archbishop of Canterbury, who is a male?
# 26
# In what area is Fernandel buried at the Passy Cemetery?
# 27
# Name the naval artillery wirh the smallest firing range?
# 28
# What is the name of a Cayenne Pepper that also has dates?
# 29
# Is the throughput of the Vest-vassdraget equal to 2697.672?
# 30
# What method did the census use to determine the population of Taguig?
# 31
# What award did Olga Tokarczuk receive in 2015?
# 32
# What is Porky Pig in right now?
# 33
# When did publisher of Pac-Man and place of publication?
# 34
# Was Aleister Crowley educated at Trinity College and Eton College?
# 35
# What is {located next to Quincy,} in the {novel, Infinite Jest}?
# 36
# Who awarded Eric Hobsbawm an honorary doctorate?
# 37
# What was the last team Allan Border belonged to in the year 1980?
# 38
# Give me a film character from a fictional universe, such as Marvel comics that starts with a W.
# 39
# Mention the fictional universe described or included in The Matrix.
# 40
# What is {award received} of {Hans Krebs} where {point in time} is {1966-0-0} ?
# 41
# Which record label signed Janet Jackson?
# 42
# What is Tanzania's total reserves?
# 43
# Does the slope rating of the Merion Golf Club equal 149
# 44
# What is the density of hydrogen peroxide at a temperature of 20.0?
# 45
# who architecture firm of home field of new york centaurs?
# 46
# Which { meansseason starts} in {February} ?
# 47
# Who is {champ} of {prize awarded} {Lily Tomlin} ?
# 48
# What is the ammunition of the weapon, that has been used in the war in Southeast Asia?
# 49
# Tell me every horse breed whose name starts with the letter z
# 50
# The University of Florida is a member of which coalition?
# 51
# Who is the brother in law of the writer Quran?
# 52
# What is the New Zealand Gazetteer place id for Auckland?
# 53
# What does the painting Grade Odalisque represent which has DRTL backwards?
# 54
# Name an empire that contains the word "british" in its name
# 55
# What is the instance of Antonio da Correggio whose date of birth is 1489-8-1?
# 56
# Who was the teacher that supervised Shigeno Yasutsugu?
# 57
# What is the SANDRE ID for Rhine?
# 58
# When did Kylie Minogue receive the Gold Logie Award for Most Popular Personality on Australian Television?
# 59
# What business does Alexander McQueen have?
# 60
# Tell me the Greek deity of sibling of Zeus and that contains the word poseidon in it's name?
# 61
# Who organizes the order of Ultima III: Exodus?
# 62
# Who was the lead actor for the movie Deadpool?
# 63
# Mention the musical related work highlighting the work of Sasha Grey.
# 64
# What award did John de Mol receive in 2011?
# 65
# Is the total fertility rate of Algeria greater than 3.4284?
# 66
# When will the pressure and temperature of water reach the triple point stage?
# 67
# Tell me physical phenomenon whose name has the word surface in it.
# 68
# where does Vladimir putin reside?
# 69
# Which is the municipality of Belgium that has the headquarters location of European Union?
# 70
# Which is made from the goat meat having a common name as Domestic Goat?
# 71
# What is located on terrain feature of Multonmah Falls?
# 72
# No item found for 'Multonmah Falls'
# Stonewall Jackson commanded what battle?
# 73
# Mention the temperature and the state of the matter of water upon achieving the critical point
# 74
# which is the point time for syria has population as 8.08815e+06?
# 75
# Does marketing involve Human communication, and packaging and labeling?
# 76
# No property found for 'Involves'
# WHICH IS THE STAGE RACE WITH THE MAXIMUM FREQUENCY OF EVENT
# 77
# WHICH IS THE AUSTRIAN MUNICIPALITY KEY OF  KLAGENFURT
# 78
# Tell me the autonomous region of the People's Republic of China which contains the word xinjiang in it's name?
# 79
# What is the Velká pardubická with the lowest race time whose winner is Peter Gehm?
# 80
# Who is the author of the Watchmen and what award did they receive?
# 81
# n/a
# 82
# Name a book written in Esperanto
# 83
# What is the general manager of Bernard Hinault?
# 84
# Name the FSK 12 rated 3D film with the highest cost ?
# 85
# How many are interested in Daniel Dennett?
# 86
# In 1996, what significant event happened in the administrative territorial entity of Bristol?
# 87
# Where is the river source of the Rhine?
# 88
# What was Cate Blanchett nominated for her work in I'm Not There?
# 89
# Tell me the tower that is depicted as Tower of Babel and contains the word babel in it's name?
# 90
# What position was held by Harold Macmillan in the 34th Parliament of the United Kingdom, when was he elected, and why did he leave?
# 91
# is the maximum wavelength of sensitivity of the human eye equal to 700?
# 92
# Where was the location of birth of Hermann Heinrich Gossen, that has Q48460 such that 2--4355126?
# 93
# No item found for 'The location of birth of Hermann Heinrich Gossen'
# Who received the Nobel Prize in Literature after Mo Yan?
# 94
# When did Eiji Toyoda win an award for his work in Order of Prince Henry?
# 95
# When was Jimmy Wales employed as Bomis and when did he leave?
# 96
# No property found for 'Employment history'
# Which is the author of afterword of Erich Fromm?
# 97
# Who are worked for Michelle Wolf and its source location of group/organisation is located in New York City?
# 98
# What are the unit of measurement which start with the letter visus
# 99
# No item found for 'Has unit symbol'
# what was the publication date for iTunes which has software version as 12.7.5?
# 100
# Dennis M. Ritchie designed which structured programming language?
# 101
# What role does Mickey Mouse play in the creative work of Ben Sharpsteen?
# 102
# What is the stock exchange for the ticker symbol 0700 in Tencent?
# 103
# What are the head of state and the office held by head of state of the Soviet Union?
# 104
# What is the name of award recieved for Dawn Fraser has participant of 1960 Summer Olympics ?
# 105
# What is the parent organization for the International Court of Justice?
# 106
# What is the beginning of Sarajevo's
# 107
# What significant event in 1978-6-1 is Michelle Bachelet known for?
# 108
# What is the solubility of methyl chloride in water?
# 109
# No property found for 'Solubility in water'
# What five U.S. states does the Delaware River drain from?
# 110
# None
# 111
# Which birth language is Chizoba Ejike?
# 112
# No item found for 'Chizoba Ejike'
# What is the ionization energy of the nicotine?
# 113
# Is tuberculosis prevalent?
# 114
# Who is {creators} of {language of the original work} {Star Trek Into Darkness} ?
# 115
# Who is the spouse of Aaliyah and when did they divorce?
# 116
# What is {inhabitants} {nationality} of {Leopold von Sacher-Masoch} ?
# 117
# What is the affiliation building in Columbia University
# 118
# What is the commune of France with the lowest population whose located in time zone is UTC+01:00?
# 119
# What is the district of the city with the MAX(number of houses whose instance of is district of the city?
# 120
# What is Bram Stoker's occupation and field of work and did he work in Dublin Castle?
# 121
# How many seasons of Handball-Bundesliga are there?
# 122
# "What is place of residence of Wangari Maathai,that has inflation rate of consumer price index as 2.9?"
# 123
# Who is the child of Pompey and the mother, Mucia Tertia?
# 124
# Name an alcoholic beverage that contains the word "rum " in its name
# 125
# How many terminus are in Vienna
# 126
# What is in the region of Paroo River, that divides into Ku-ring-gai Council?
# 127
# No item found for 'Paroo River Region'
# What has been the ister city of Changchun since Aug 25th, 1992?
# 128
# How many rivers and lakes are connected to Lake Urmia?
# 129
# Tell me soil type whose name has the word vertisol in it.
# 130
# What is Lizzy Yarnold's TheSports.org athlete ID?
# 131
# What is { award received } from { Justin Timberlake } that is { point in time } is { 2007 - 0 - 0 }?
# 132
# Which religious concept starts with the letter t
# 133
# Is it true that the explosive energy equivalent of Father of All Bombs is less than 52.8?
# 134
# When did child of Abigail Adams and date of birth?
# 135
# Does the Becherovka alcohol by volume less than 30.4
# 136
# What are the prefecture-level city  which start with the letter ürümqi
# 137
# tell me ceremony whose name has the word umhlanga in it
# 138
# Which is {played as} of {symbol} of {inequality} ?
# 139
# What is edition runtime for League of Legends?
# 140
# What is the name of the Dutch municipal coat of arms of Amsterdam?
# 141
# No property found for 'municipal coat of arms'
# Which is the sauce that originated in Korea?
# 142
# How many depositors are with the {United Nations Secretary-General} ?
# 143
# No property found for 'Depositor'
# Which is the electric charge for antihydrogen?
# 144
# Who gave the {is shown in} of {based upon} of {Clark Kent} ?
# 145
# How far west are we?
# 146
# Tell me national association football team whose name has the word team in it.
# 147
# Tell me the most notable work of Christopher Hitchens and also the publisher.
# 148
# What is the INSEE countries and foreign territories code for the Democratic Republic of Congo?
# 149
# No item found for 'INSEE country code'
# What is the warheroes.ru ID for Yuri Gagarin?
# 150
# Is the diameter pf nickel equal to 0.807?
# 151
# Is the stated age of Rolf-Axel Eberhardt greater than 52?
# 152
# When Podgorica started as Principality of Montenegro?
# 153
# IS THE ENTHALPY OF VAPORIZATION OF METHANOL IS EQUAL TO 37400
# 154
# What award was received Mary Tyler Moore ?
# 155
# what is Tuesday named after?
# 156
# How many of the archives are for Grace Hopper?
# 157
# Which is the narrative location of Siddhartha?
# 158
# Where is the place of Tartuffe's first performance with the farthest east coordinates of 48.8363848 2.4697602?
# 159
# What are the military operation which start with the letter o
# 160
# Is the matches/games drawn/tied of the 2001 British and Irish Lions tour to Australia equal to 0?
# 161
# Who is the mother and husband of Candice Bergen?
# 162
# "Which language written from Romy Schneider, has the grammatical person speaking as the third personal plural?"
# 163
# Does the cash back of the Gold  ADAC Credit Card equals 5?
# 164
# Who is the opposite of the superhero?
# 165
# What is the use of playing World Rugby?
# 166
# What is the current population of Aden?
# 167
# what is spouse of Carlos Saura that is start time is 2006?
# 168
# How many numbers of exclave for the  {Azerbaijan} ?
# 169
# Which is the total equity of Micron Technology?
# 170
# Was Michael J. Fox's place of birth in Edmonton?
# 171
# What is Palace of Westminster's architect and heritage designation?
# 172
# is it true that the SSK6-1s optimum viable temperature is greater than 24.0?
# 173
# Which country housed the Indian Independence Movement?
# 174
# No property found for 'Location of Indian Independence Movement'
# Name a nonmetal discovered in England  that starts with letter O
# 175
# What did Sidney Crosby draft?
# 176
# How many shogun military ranks are there?
# 177
# No item found for 'shogun military rank'
# Who was presumably thought to be a student of Strabo?
# 178
# What position did John Hume hold, when was he elected, and what position did he hold in the 53rd Parliament of the United Kingdom?
# 179
# Who is the son of Jacob Conover?
# 180
# Gordon Lightfoot was nominated for what at what time?
# 181
# What is John X's persumed date of date according to sourcing circumstances?
# 182
# No property found for 'Presumed date of death'
# Which is the patron saint of the place of death of Anna de' Medici?
# 183
# Is it true that the fee of Harvard University is less than 90?
# 184
# What is BIA PSY person ID for Carl Rogers ?
# 185
# Who is the captain of F.C. Porto?
# 186
# What are the autonomous region of the People's Republic of China which start with the letter X
# 187
# What is the time zone that Marseille is located in?
# 188
# What award did Harry Martinson adn Eyvind Johnson receive together?
# 189
# Mention the headquarter location of the Russian Orthodox Church monastery.
# 190
# What is Bandysidan player ID for Sergey Lomanov ?
# 191
# Who are the writers of the academic subject Ten simple rules for editing Wikipedia?
# 192
# Name the female who discovered the Horsehead Nebula.
# 193
# Name a fruit composed of Citrullus lanatus that starts with letter W
# 194
# What conflict is depicted is Raising the Flag on Iwo Jima?
# 195
# What what is unary operation notation by integral symbol and which that starts with {'i'}
# 196
# No item found for 'Unary operation notation'
# What is being treated in an individual with arteriosclerosis?
# 197
# What is the category for recipients for the Noble Prize?
# 198
# At what rate was inflation in Venezuela in the year 1996?
# 199
# When was Vittorio De Sica nominated for an Academy Award for Best Supporting Actor?
# 200
# What is Auñamendi ID of Miguel López de Legazpi ?
# 201
# What is the timezone of the place Sallust died?
# 202
# Did the East India Company own the Britannia and the Busbridge?
# 203
# Which is the ISNI for Marit Bjørgen?
# 204
# What is total fertility rate of Trinidad and Tobago that is determination method is estimation process ?
# 205
# Which church is located in the parish border Krukengrund?
# 206
# What was Philip Roth nominated for in 2011?
# 207
# Where is the deathplace of Gediminas, whose twin town is Irkutsk?
# 208
# What is the fuel system of electricity?
# 209
# In the 68th Academy Awards, what nomination did Mira Sorvino receive?
# 210
# Tell me interface standard whose name has the word virtuallink in it.
# 211
# No property found for 'Interface standard name'
# What is Ferenc Molnar's compArt person ID?
# 212
# Which is the Great Aragonese Encyclopedia ID for Allium cepa?
# 213
# Tell me medical specialty whose name has the word trichology in it.
# 214
# how many performances are by jimi hendrix?
# 215
# What is the state of India that contain the word "uttarakhand" in its name ?
# 216
# Who is drafted by the Boston Celtics?
# 217
# Name the BAFTA settlement with the postcode DA.
# 218
# Is the maximum number of players for the coxless four 0.0?
# 219
# Name a religious concept in Hinduism that contains the word "yatra" in its name
# 220
# Which is the golf course arena carrying designs patterns of Donald Trump?
# 221
# n/a
# 222
# What is the religious affiliation of Vladimir the Great's child?
# 223
# What was the population of the Maldives in 1967?
# 224
# What year did Le Corbusier win the Frank P. Brown Medal?
# 225
# No property found for 'Award name'
# Tell me the city which is enclaved within Montreal.
# 226
# who was the pope replaced by?
# 227
# Is it true that the minimum wavelength sensitivity of the Giant Magellan Telescope is 320?
# 228
# Which is a used metre of lliad?
# 229
# "Where is {on harbour} of {Kryvyi Rih}, which has {tributary} is {Saksahan} ?"
# 230
# Who stars with Ian Carlyle in the production?
# 231
# What causes rain?
# 232
# What is the service branch  by Julius and Ethel Rosenberg, which has subsidiary entities including Arlington National Cemetery?
# 233
# Was Hank WIlliams a rockabilly and honky-tonk musician?
# 234
# When did Aaron Kwok receive the award for Golden Horse Award for Best Leading Actor?
# 235
# When did Marco Polo marry Donata Badoer?
# 236
# Who was Al Gore's spouse beginning in 1970?
# 237
# What appearance of a Christmas tree happens every January 19?
# 238
# What is the home venue of the Green Bay Packers?
# 239
# Which is the enterprise for the parent organization of Sears?
# 240
# Who proved the theory of Proper Motion? Their surname is Halley.
# 241
# What head coach is the New York Yankees named after?
# 242
# What are the national cuisine which start with the letter m
# 243
# Which is the television series which contains the word zigby in it's name?
# 244
# Tell me about spouse of Barbara Walters and start time?
# 245
# What is the second language of Peter Faber which regulatory body is Pontifical Academy of Latin?
# 246
# What is the honorary title given to Albert Gunther which was won by P.A. Buxton?
# 247
# Is it true that the topographic isolation of Pollux equals to 0.7?
# 248
# What award did Edward C. Prescott receive on 1-1-2004?
# 249
# where is the headquartes of  formation of google located?
# 250
# What is melody of Tristan und Isolde ?
# 251
# What time has Manhattan listed as the end time for a maritime evacuation event?
# 252
# What has the eccentricity of 0.0567, that is located on astronomical body of the near side of the moon?
# 253
# What is the diplomatic relations like in basin countries of Lake Okeechobee?
# 254
# What two cities hold the principle offices of Financial Times?
# 255
# No property found for 'Principle Office'
# How many active ingredients are in lidocaine?
# 256
# Where was Augustus II the Strong buried?
# 257
# Is it true that the semi-major axis of 1627 Ivar is greater than 2.2361778?
# 258
# What is the CBS municipality code of Nijmegen?
# 259
# Was Herbie Hancock the winner of the award for the Grammy Award for Best Pop Collaboration with Vocals?
# 260
# What is the total fertility rate of Sudan with estimation process?
# 261
# Is the half-life of silicon-36 less than 0.54?
# 262
# What is a sovereign state for office held by the pope's head of state?
# 263
# What is the Malayalam alphabet?
# 264
# Which programming language did Dennis M. Ritchie create?
# 265
# WHICH IS THE ZUCKERART THAT CONTAINS WITH THE WORD SYRUP IN THER NAME
# 266
# Which reward was The Diary of Anne Frank a nominee for?
# 267
# Name a business whose heaquarters are located in Lyon
# 268
# What is the Commons category of Classic of Poetry ?
# 269
# Who was married to Ida Lupino on January 1st, 1951?
# 270
# What agent had conflict with Lowell English?
# 271
# What does European Parliament approve?
# 272
# WHat location that belongs to the World Heritage starts with the letter H
# 273
# mike krzyzewski name
# 274
# What is Fantastic Fiction author ID of James Ellroy?
# 275
# Where was Syrie Maugham's country of citizenship in 1927?
# 276
# "Who is {took part in} of {boy}, which has {theatre season} is {classical antiquity} ?"
# 277
# What administrative territorial entity was Sint Maarten located in the year December 15, 1954?
# 278
# What is the density of aluminium at a temperature of 20 degrees?
# 279
# What is the country of citizenship and the religion of Elizabeth_Smart ?
# 280
# Which is the GeneReviews ID for Alzheimers disease?
# 281
# When did Artem Sergeev, adopted son of Joseph Stalin, die?
# 282
# "What is {holds position} of {Martin McGuinness}, which has {prequel of} is {Member of the 55th Parliament of the United Kingdom} ?"
# 283
# What what is animated taxondistributed by MGM and {family}
# 284
# Which is the SAHRA heritage site ID for University of Cape Town?
# 285
# What is the CPU with the greatest charge?
# 286
# When did Sarah Bernhardt and Jacques Damala split up?
# 287
# "What is the birth city of Kirsten Stewart, with the county seat of Los Angeles County?"
# 288
# Where {faith} {has influence} on {Madonna} ?
# 289
# What in the code for INS?
# 290
# When did Alla Pugacheva divorce his wife, Mykolas Orbakas?
# 291
# When was Isadora Duncan's funeral?
# 292
# Which is the gens of Sallust?
# 293
# who culture of state of australian secret intelligence services ?
# 294
# What are the opening hours for Thursday?
# 295
# What language does the sculptor of Z3 write in?
# 296
# What award did I.M. Pei receive in 2010?
# 297
# "Where is {deathplace} of {Amelia Earhart}, which has {tributary} is {Ayampe River} ?"
# 298
# Was Cleopatra's child named Caesarion?
# 299
# When did Barry Humphries receive the Centenray medal?
# 300
# Which chemical compound has the most binding energy?
# 301
# When did Abigail Adams father die, and who was he?
# 302
# What was the population of Washington, D.C. at the start of 1860?
# 303
# Did Mao Zedong hold a position as President of the People's Republic of China?
# 304
# What effects does arsenic have at the minimal lethal dose of 300?
# 305
# Is it true that the maximum wavelength of sensitivity of Submilimeter Array is greater than 2.004?
# 306
# What nonprofit organization is regulated by the association of football?
# 307
# What diplomatic crisis lead to the founding of the Russian Orthodox Church?
# 308
# Which is the spacecraft that is manufactured by SpaceX?
# 309
# When was Boris Johnson the Member of the 56th  Parliament of the United Kingdom?
# 310
# who  is the city for capital of wales?
# 311
# Which is the Commons gallery for Georges Seurat?
# 312
# What is a nut that starts with the letter n.
# 313
# When is the date and birth of Joseph Stalin's child with Svetlana Alliluyeva?
# 314
# How many works are occupied in the Rijksmuseum?
# 315
# Where is the archive for archives of The Walt Disney company?
# 316
# No item found for ''
# What is the work of Jack Warner awarded as Academy Award for Best Picture?
# 317
# What is the birthplace of Maureen O'Hara, which has the co-ordinate location of 53.3252?
# 318
# What is the official residence of Queens?
# 319
# Which is the {participant} and the {location} of {Pacific_War} ?
# 320
# To whom did Gerard Reve got married and when did it end?
# 321
# What domain has the aspect of bodhisattva?
# 322
# What is the Commonwealth area with the lowest real gross domestic product growth rate whose diplomatic relation is Taiwan?
# 323
# What is located on the astronomical body of North America?
# 324
# Who is the owner of the theatre company that made 'The Birth of the Star Spangled Banner'?
# 325
# How did John Wilkes Booth kill Abraham Lincoln?
# 326
# What sovereign state belonging to the International Finance Corporation has the lowest unemployment rate?
# 327
# Who was the person with Chris Rock when he was awarded the Lunt-Fontanne Award for Ensemble Excellence?
# 328
# What does Kelly Clarkson do and where is she a citizen?
# 329
# What is the Uppslagsverket Finland ID for kickboxing?
# 330
# How many different kinds of industry are affected by furniture?
# 331
# When did Lee de Forest divorce from Nora Stanton Blatch Barney?
# 332
# Mention the predecessor and the successor of Louis the Pious while being recognized as king of Franks
# 333
# does the explosive energy of the tsar bomba equal 500
# 334
# What is the bibliography of the  PhD advisor to Karl Herzfeld?
# 335
# What is the interaction of antiparticle symmetric correspondence with Q48460 521.1?
# 336
# What is the estimation rate of Slovakia fertility?
# 337
# Tell me {intergovernmental organization}  whose name  starts with s
# 338
# Is it true that the Wu Tang Clan signed with Loud Records and Ruff Ryders Entertainment?
# 339
# what is stable version of user interface of amazon kindle?
# 340
# which award E.T. the Extra-Terrestrial did receive and at what time he got it?
# 341
# What is the music genre that is made by Battle Zeque Den
# 342
# When did Ronna Romney McDaniel become chairperson of the Republican Party?
# 343
# No item found for 'Chairperson of the Republican National Committee'
# Which is the Basketball-Reference.com NBA player ID of Hakeem Olajuwon?
# 344
# What are the beliefs of the Chinese Communist Party's Chair, Hu Jintao?
# 345
# What is { solubility } of { nitrous oxide } { solvent } is { water }?
# 346
# What type of beryl is found at he GPS coordinates of 24.77111111 34. 71805556?
# 347
# Which {history of topic} and the {geography of topic} is {Melbourne} ?
# 348
# What is the sister city of Ivan Turgenev's hometown?
# 349
# Who was the teacher of the musical score of Suite 1922?
# 350
# Is a black hole the opposite of a stellar atmosphere?
# 351
# Did Francis Ford Coppola have notable works of The Godfather and The Godfather Part III?
# 352
# tell me audio and video interfaces and connectors are name has the word ypbpr in it
# 353
# What is the official language of lives in Pasi Siltakorpi?
# 354
# How many colors are next to brown
# 355
# No property found for 'Adjacent color'
# What is the active ingredient pharmaceutical product in erythromycin?
# 356
# Is the PPP GDP per capita of Lithuania less than 22148.8
# 357
# Is the topographic prominence of the Franzosenkopf less than 4.0?
# 358
# What Chinese dynasty replaced the Yuan dynasty?
# 359
# How would you spell meat pie using the international phonetic alphabet?
# 360
# Where is the human place of birth in Thessaloniki?
# 361
# What is Anthony Vivaldi's CPDL ID?
# 362
# did john grisham have a degree in law in the University of mississippi school of law?
# 363
# Who else participated in Deep Blue with top dog Cray Blitz?
# 364
# What is GACS ID for West Africa?
# 365
# When did Johnny Carson start as the presenter for The Tonight Show?
# 366
# How many armament does the aircraft has?
# 367
# Where and what did Katherine Dunham study?
# 368
# Name the women's association football team who play the least in tournaments.
# 369
# How many input methods are on a computer keyboard?
# 370
# Tell me me a cryptocurrenc whose name consist of the word "neo" and whose stock exchange bitfinex
# 371
# What are Jews the opposite of and for whom are they named?
# 372
# What explosive chemical has the highest explosive velocity ?
# 373
# Is the human genome size more than 3881796000?
# 374
# Where is the drainage basin of the Brazos River?
# 375
# Who is C. V. Raman's doctor
# 376
# Who is the viceroy of Tasmania?
# 377
# No item found for 'Viceroy of Tasmania'
# What is at the Kolyma River at the coordinates 161.364?
# 378
# What is the court and application of jurisdiction of Roe v. Wade?
# 379
# What are the phantom island which start with the letter T
# 380
# Which German city is twinned with Cardiff?
# 381
# How many games did Just Fontaine play for the O.G.C. Nice and how many goals did he score?
# 382
# What position does David Lloyd George hold?
# 383
# What portrait has the Woman Drinking Wine wearing a pendant?
# 384
# Cholera affects which taxon?
# 385
# Is Schutzstaffel's subsidiary Reich Main Security Office and 21st Waffen Mountain division of the SS Skanderbeg?
# 386
# In the consort of Myrna Loy, what is the service branch?
# 387
# No property found for 'Consort'
# When did Supernatural win the Favorite Pop/Rock Album award?
# 388
# What is the international organization for World Bank?
# 389
# What was the population of Aysén Region from 1992-0-0?
# 390
# What are the historical progress which start with the letter g
# 391
# what was the position held by john major and when did it end?
# 392
# Matthias Sindelar who has number of points/goals/set scored as 26.0 is a member of which sports team ?
# 393
# TELL ME TRADITIONAL FAIRY TALE WHOSE NAME HAS THE WORD SNOW IN IT.
# 394
# Which award did One Piece receive in 2009?
# 395
# What is the number of original networks owned by the Discovery Channel?
# 396
# WHO IS THE PARENT OF SON FRANCESCO I SFORZA ?
# 397
# Where does Po fit into the location 12.5469?
# 398
# Which are the cites of Tractatus Logico-Philosophicus?
# 399
# What has the Pokedex number 36 and follows Pikachu?
# 400
# What are the fictional detective which start with the letter s
# 401
# "Who is {nomination received} of {George Marshall}, which has {champion} is {Mikhail Gorbachev} ?"
# 402
# Who is the showrunner of The Apprentice, who also has a sister called Robert Trump?
# 403
# Were Dutch and Hungarian the official languages of the Holy Roman Empire?
# 404
# What type of clothing do the characters in The Silent Stars Go By wear?
# 405
# How do you pronounce coffee in the Georgian language?
# 406
# tell me demigod of Greek mythology wears hide  starts with h
# 407
# What is the cardinality of the complex logarithm input set?
# 408
# No property found for 'Complex logarithm input set'
# Tell me the famine which starts with the letter t?
# 409
# WHO DIRECTS THE POLITICAL OFFICE HELD IN EDUARDO LOPEZ DORIGA
# 410
# What position is held by Ramsay MacDonald and when was he elected?
# 411
# tell me about thoracic disease that contains the word syndrome in their name
# 412
# what is the world heritage Tentative liste ID of  Univirsity of Tahran
# 413
# What language did Juan González de la Pezuela y Ceballos translate for Os Lusíadas?
# 414
# "Who is {tenant} of {Windsor Castle}, that has {employment} as {postage stamp designer} ?"
# 415
# When did Veronica Lake and Andre dé Toth end their relationship?
# 416
# which was the series ordinal  for ether which has  ionization energy as 9.53?
# 417
# Is normal distribution named after Bernhard Riemann?
# 418
# Is the apoapsis of the Aotearoa 3400 equal to 2.126?
# 419
# Which bourbon whisky has the lowest alcohol by volume whose country of origin is united states of america?
# 420
# No item found for 'discontinued distillery'
# What is the genetic association of major depressive disorder with the determination method TAS?
# 421
# When did the Three Kingdoms period end in Korea?
# 422
# What book series did the author Dante Alighieri write?
# 423
# Tell me biogeochemical cycle whose name has the word cycle in it.
# 424
# What business, product, or material does Facebook offer?
# 425
# WHICH IS THE ASSOCIATION OF FOOTCLUB THAT STARTS WITH W
# 426
# Into how many editions has Othello been translated?
# 427
# What was the result found in the species of hypothetical protein ipg2828?
# 428
# Where was professor Dimitri Mendeleyev educated, and what is his expertise?
# 429
# What team did Peter Schmeichel start playing for in 1984?
# 430
# Where is the name of the continent of the mountain belt in Mount Caywood?
# 431
# Is Azcapotzalco in the Mexico City administrative territory?
# 432
# Which are the grants academic degrees for Master of Business Administration?
# 433
# No property found for 'educational credential awarded'
# what was the country of Tyumen in 1991-12-27
# 434
# Who regulates the genetic association of hsa-miR-5006-3p in molecular biology
# 435
# Is the toughness of Grivory GM-4H less than 7.2?
# 436
# what is {PhD advisor} of {favorite player} of {Anthony Giddens, Baron Giddens} ?
# 437
# Name an unity of measure used for temperature that starts with letter P
# 438
# What is the temperature of toxaphene that has a density of 1.65?
# 439
# "What is name of John Foster Dulles Latin script that has alphabet?"
# 440
# Is Ridley Scott the child of Luke Scott and Jordan Scott?
# 441
# Which new conference did Donald Trump participate in?
# 442
# who unit of density for measured by of density?
# 443
# Tell me the point in time for Pierre de Fermat has academic degree as Bachelor of Laws?
# 444
# Which  anatomical location of place built of zygote ?
# 445
# No property found for 'Has anatomical location'
# Which is Greek nymph which was the partner of Apollo?
# 446
# When did Prince Philip, Duke of Edinburgh use the Arms of Philip Mountbatten (1947-1949) as his coat of arm?
# 447
# Who was nominated for an Academy Award for  Best Sound Mixing in Gladiator?
# 448
# What are the national sports team  which start with the letter t
# 449
# What children did the brothers and sisters of Emmanuel Philibert, Prince of Carignano, have?
# 450
# At what role did John Tyler replace William Henry Harrison?
# 451
# Which is FIFA player ID for Stanislav Cherchesov?
# 452
# Who is {followed by} and {follows} of {{Guy of Lusignan} has {noble title} as {King of Jerusalem}}
# 453
# Which is the historic era in Epaminondas having completed in 600-1-1?
# 454
# What was George Washington's military rank between 1774 and 1796?
# 455
# What was Laurence Olivier nominated for at the 12th Academy Awards?
# 456
# Which is the Crossref funder ID of the National Museum of American History?
# 457
# What is the SIRUTA code of Constanta?
# 458
# Whats the Brockhaus Enzyklopadie online ID of Chile?
# 459
# Name a Luther city that contain the word "worms " in its name
# 460
# When did Roman Abramovich marry Irina Abramovich?
# 461
# Is it true that the target interest rate of Central Bank of Azerbaijan equals to 5.25?
# 462
# Was Rupert Grint's occupation a actor and child actor?
# 463
# Was Hugh_Grant relative Rick Cosnett?
# 464
# Which is stated in Tripitaka?
# 465
# What is the  Mississippi Sports Hall of Fame ID  for Brett Favre ?
# 466
# What is the academic area of work of Viktor Bespalov?
# 467
# Which is the GCatholic church ID of Archbasilica of St. John Lateran?
# 468
# Roger Milla was a member of which sports teams and how many matches did he play?
# 469
# When did the marriage between Marilyn Monroe and James Dougherty end?
# 470
# Which is the Kinopoisk person ID for Stanley Donen?
# 471
# Name a disease that starts with the letter Y
# 472
# What is on geographical feature of Greater Antilles whose continent is North America ?
# 473
# No property found for 'located on continent'
# Ignatius of Loyola belongs to which Catholic order?
# 474
# What is the {product} of {papermaking} which is {made of} {bleach} called?
# 475
# What happened to the SS Naronic?
# 476
# What is {chairwoman} of {working for} of {Vannevar Bush} ?
# 477
# Who was Jonas Salk's doctoral student?
# 478
# Shen Bao has a partner city of Rotterdam, what is the main location of the publication?
# 479
# What are the regions available on the coast of Lower Saxony?
# 480
# How many medical conditions are treated by diazepam?
# 481
# Do the rural cities of Para have 13155 inhabitants?
# 482
# No property found for '13155 inhabitants'
# What position did William Carmichael replace John Jay in?
# 483
# What are the type of food or dish that contains the word torta in their name
# 484
# which type of quantum particle has highest gyromagnetic ratio?
# 485
# Tell me literary genre whose name has the word vita in it
# 486
# Which equation do I use to measure horsepower ?
# 487
# What is the parent company of those who work at Roberta Bondar?
# 488
# What is the official language of Alice springs-Soverign state?
# 489
# What is the text input for the Aruba flag emoji?
# 490
# What is native language for Vincent Auriol ?
# 491
# Name a memer of the Oracle Corporation
# 492
# Name a musical composition by Dionysus
# 493
# Who was the goddess Artemis?
# 494
# What position did Martin V hold that was eventually replaced by Eugene IV?
# 495
# None
# 496
# What was the {award won} by {Cream}, that was {introduced} in {1983-0-0}?
# 497
# Which  is farthest north of place held by Balkans Campaign?
# 498
# What is Jacinda Ardern's position ?
# 499
# 500
# CPU times: user 37.4 s, sys: 5.3 s, total: 42.7 s
# Wall time: 1h 6min 15s

# %%
len(queries)
# Out:
# 500

# %%
serialized_list = json.dumps(queries)

with open("gpt3_turbo_queries.json", "w") as output_file:
    output_file.write(serialized_list)

# %%
# %%time
v = validate_queries(queries)
# Out:
# 0
# SELECT ?country ?tax_rate WHERE { ?country wdt:P31 wd:Q6256 . ?country wdt:P297 ?iso_code . ?country wdt:P710 ?tax . ?tax wdt:P17 ?country . ?tax wdt:P2 ?tax_type . FILTER(?tax_type = wd:Q1056898) BIND(xsd:decimal(?tax) as ?tax_rate) } ORDER BY DESC(?tax_rate) LIMIT 1
# 1
# SELECT ?date WHERE { ?Q51929074 rdfs:label "James Thomas Farrell"@en . ?Q51929074 wdt:Q43380 ?Q618779 . ?Q618779 rdfs:label "St. Louis Literary Award"@en . ?Q618779 wdt:Q47150325 ?date . } limit 100
# 2
# SELECT ?end_date WHERE { wd:Q5593 wdt:P451 ?partner . ?partner wdt:P582 ?end_date . ?partner rdfs:label 'Fernande Olivier'@en . } limit 100
# 3
# SELECT ?productLabel WHERE { ?product wdt:P31 wd:Q542929 . ?product wdt:Q70339049 ?consumptionRate . ?product wdt:Q96775080* wd:QINSERT . FILTER NOT EXISTS { ?product wdt:Q96775080 ?subProduct . ?subProduct wdt:Q70339049 ?subConsumptionRate . FILTER(?subConsumptionRate < ?consumptionRate) } } ORDER BY ?consumptionRate LIMIT 1 SERVICE wikibase:label {  wikibase:language 'en'. ?product Q18127 ?productLabel. }
# Request failed with status code 400
# Failed query number 3
# 4
# SELECT ?latitude ?longitude WHERE { wd:Q1166 wdt:P625 ?coordinates . ?coordinates wdt:P6258 ?latitude . ?coordinates wdt:P6257 ?longitude } limit 100
# 5
# SELECT ?result WHERE { wd:Q252 wdt:Q188419 ?life_expectancy . FILTER(?life_expectancy = 55.3528) BIND(xsd:boolean(?life_expectancy = 55.3528) as ?result) } limit 100
# 6
# SELECT ?start_date WHERE { wd:Q510523 wdt:P69 ?education . ?education wdt:P1711 wd:Q2096836 . ?education wdt:P580 ?start_date . } limit 100
# 7
# SELECT ?career WHERE { wd:Q553072 wdt:P106 ?occupation . ?occupation wdt:p-SubclassOf* wd:Q115156386 . ?occupation rdfs:label ?career . FILTER(LANG(?career) = 'en') } limit 100
# 8
# SELECT ?habitat WHERE { ?protein wdt:P688 ?gene . ?gene wdt:P703 ?species . ?protein rdfs:label "hypothetical protein ecia139-4120"@en . ?species rdfs:label "{{Q7432}}"@en . ?protein wdt:P2974 ?habitat . } limit 100
# 9
# SELECT Q72940387 WHERE { wd:Q161885 Q21503252/Q21503252/Q61268336* wd:Q3624078 . Q72940387 Q21503252/Q21503252/Q61268336* wd:Q3624078 . Q72940387 Q24575109 wd:Q161885 . } limit 100
# Request failed with status code 400
# Failed query number 9
# 10
# SELECT ?result WHERE { wd:Q671965 wdt:P4912 ?century_break . FILTER(?century_break <= 9.6) BIND(xsd:boolean(?century_break <= 9.6) as ?result) } limit 100
# 11
# SELECT ?countryLabel WHERE { wd:Q79965 wdt:P625 ?country . ?country wdt:p-Instance_of wd:Q83440 . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# 12
# SELECT  WHERE { ?city wdt:P361 Q57525 . ?city wdt:P190 Q158491 . ?city wdt:P36  . } limit 100
# Request failed with status code 400
# Failed query number 12
# 13
# SELECT ?date WHERE { ?country rdfs:label "Nicaragua"@en . ?country wdt:P1082 ?population . ?population wdt:Q186408 ?date . FILTER(?population = 3.87732e+06) } limit 100
# 14
# SELECT ?definition WHERE { wd:Q187668 wdt:P2325 ?definition . SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } } limit 100
# 15
# SELECT Q37178026 WHERE { Q37178026 wdt:P128 wd:Q2736 . Q37178026 wdt:P31 wd:Q37178026 } limit 100
# Request failed with status code 400
# Failed query number 15
# 16
# SELECT ?divorce_date WHERE { wd:Q1413 p:P26 ?spouse_statement . ?spouse_statement ps:P26 wd:Q1196129 . ?spouse_statement pq:P580 ?start_time . OPTIONAL { ?spouse_statement pq:P582 ?end_time } FILTER(?start_time <= "9-6-68"^^xsd:dateTime) FILTER(!bound(?end_time) || ?end_time >= "9-6-68"^^xsd:dateTime) BIND(xsd:string(?end_time) as ?divorce_date) } limit 100
# 17
#  limit 100
# Request failed with status code 400
# Failed query number 17
# 18
# SELECT ?award WHERE { ?champion wdt:P2517 wd:Q325945 . ?champion wdt:P166 ?award . ?champion wdt:P1346 ?competition . ?champion wdt: wd:Q80892 . } limit 100
# 19
# SELECT ?result WHERE { wd:Q118373 wdt:P4130 ?survivor . { SELECT (COUNT(?survivor) as ?count) WHERE { wd:Q118373 wdt:P4130 ?survivor } } FILTER(?count > 0) BIND(xsd:boolean(?count > 0) as ?result) } limit 100
# 20
# SELECT ?date WHERE { ?secretariat wdt:Q21096945 ?award . ?award wdt:Q21503252 wd:Q618779 . ?award wdt:Q420477 wd:Q1151926 . ?award wdt:Q21096945 wd:Q7843370 . ?award wdt:Q186408 ?date . FILTER(lang(?date) = 'en') } limit 100
# 21
# SELECT ?result WHERE { ?r1 wdt:P47 ?r2 . ?r2 wdt:P276 wd:Q486972 . ?r1 wdt:P276 wd:Q486972 . ?r1 wdt:P580 ?start_date . FILTER(?start_date = xsd:dateTime('1984-01-01T00:00:00Z')) BIND(xsd:boolean(?start_date = xsd:dateTime('1984-01-01T00:00:00Z')) as ?result) } limit 100
# 22
# SELECT ?facilityLabel WHERE { ?defensive_wall wdt:P846 ?facility . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# 23
# SELECT ?lighthouse_number WHERE { ?dictionary_item rdfs:label "IHO Hydrographic Dictionary (S-32)"@en . ?dictionary_item wdt:P527 ?lighthouse . ?lighthouse wdt:P31 wd:Q39715 . ?lighthouse wdt:P4423 ?lighthouse_number } limit 100
# 24
# SELECT ?fictional_analog WHERE { ?fictional_analog wdt:P31 Q2593744 . ?fictional_analog rdfs:label ?label . FILTER(LANG(?label) = 'en' && LCASE(?label) = LCASE('Hippocampus')) } limit 100
# Request failed with status code 400
# Failed query number 24
# 25
# SELECT ?cause_of_death WHERE { ?cause_of_death wdt:P31 wd:Q146 . ?cause_of_death wdt:P828 ?scan_technique . ?cause_of_death wdt:P509 ?cause_of_death_manner_of_death . FILTER(STRSTARTS(LCASE(?cause_of_death_manner_of_death), 'p') && LCASE(?scan_technique) = 'ct scan') } limit 100
# 26
# SELECT Q574562 WHERE { Q574562 Q23058136 Q105080069 . Q574562 Q1775415 Q6581097 } limit 100
# Request failed with status code 400
# Failed query number 26
# 27
# SELECT Q15060255 WHERE { wd:Q129092 wdt:P119/wdt:P131* wd:Q1092107 . wd:Q1092107 wdt:P276 ?area . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# Request failed with status code 400
# Failed query number 27
# 28
# SELECT ?naval_artillery ?firing_range WHERE { ?naval_artillery wdt:P31 wd:Q18616576 . ?naval_artillery wdt:P1072 ?firing_range . FILTER NOT EXISTS { ?naval_artillery wdt:P31 wd:Q15720608 } } ORDER BY ASC(?firing_range) LIMIT 1
# 29
# SELECT ?cayenne_pepper_name WHERE { ?cayenne_pepper wdt:P652 wd:Q6598 . ?cayenne_pepper wdt:P652 wd:Q81204096 . ?cayenne_pepper rdfs:label ?cayenne_pepper_name . FILTER(LANG(?cayenne_pepper_name) = 'en') } limit 100
# 30
# SELECT ?result WHERE { wd:Q58370919 wdt:P2957 ?throughput . FILTER(?throughput = 2697.672) BIND(xsd:boolean(?throughput = 2697.672) as ?result) } limit 100
# 31
# SELECT ?method WHERE { wd:Q1643 wdt:P1082 ?population . ?population wdt:P459 ?method . } limit 100
# 32
# SELECT ?award WHERE { ?person rdfs:label "Olga Tokarczuk"@en . ?person wdt:P166 ?award . ?award wdt:P585 ?date . FILTER(YEAR(?date) = 2015) } limit 100
# 33
# SELECT ?result WHERE { wd:Q937186 wdt:P31 ?result . } limit 100
# 34
# SELECT ?publisher ?place_of_publication WHERE { wd:Q173626 wdt:P123 ?publisher . wd:Q173626 wdt:P291 ?place_of_publication } limit 100
# 35
# SELECT ?result WHERE { wd:Q172684 wdt:P69 wd:Q332342 . wd:Q172684 wdt:P69 wd:Q192088 . BIND(xsd:boolean(EXISTS { wd:Q172684 wdt:P69 wd:Q332342 . wd:Q172684 wdt:P69 wd:Q192088 . }) AS ?result) } limit 100
# 36
# SELECT ?result WHERE { ?novel rdfs:label "Infinite Jest"@en . ?novel wdt:P625 ?location . ?location rdfs:label "Quincy"@en . ?location wdt:P3032 ?result } limit 100
# 37
# SELECT ?awarding_institution WHERE { ?honorary_doctorate wdt:P166 ?person . ?honorary_doctorate wdt:P1035 "Honorary Doctorate" . ?honorary_doctorate wdt:P166 ?awarding_institution . FILTER(CONTAINS(LCASE(?personLabel), LCASE("Eric Hobsbawm"))) } limit 100
# 38
# SELECT ?team WHERE { ?player wdt:P54 ?team ; wdt:P106 wd:Q1392194 ; wdt:P569 ?year . FILTER(?year = 1980) FILTER NOT EXISTS { ?player wdt:P582 ?end_date . FILTER(?end_date > "1980-12-31T23:59:59Z"^^xsd:dateTime) } } ORDER BY DESC(?player) LIMIT 1
# 39
# SELECT ?characterLabel WHERE { ?character wdt:P31 wd:Q95074 . ?character wdt:P674 ?universe . FILTER(CONTAINS(LCASE(?universeLabel), LCASE('fictional universe'))) . ?character wdt:P674 ?universe . FILTER(CONTAINS(LCASE(?universeLabel), LCASE('marvel comics'))) . ?character rdfs:label ?characterLabel . FILTER(CONTAINS(LCASE(?characterLabel), LCASE('W'))) . FILTER(LANG(?characterLabel) = 'en') } limit 100
# 40
# SELECT ?universeLabel WHERE { wd:Q193825 wdt:P973 ?universe . ?universe rdfs:label ?universeLabel . FILTER(LANG(?universeLabel) = 'en') } limit 100
# 41
# SELECT ?award_received WHERE { wd:Q57191 p:P166 ?award_statement . ?award_statement ps:P166 ?award_received ; pq:P585 ?time . FILTER(?time >= "1966-01-01T00:00:00Z"^^xsd:dateTime && ?time <= "1966-12-31T23:59:59Z"^^xsd:dateTime) } limit 100
# 42
# SELECT ?record_label WHERE { ?Q131324 jackson:artistName "Janet Jackson" . ?Q131324 wdt:P264 ?record_label . ?record_label wdt:P31 wd:Q18127 . } limit 100
# Request failed with status code 400
# Failed query number 42
# 43
# SELECT ?total_reserves WHERE { wd:Q924 p:P28 ?statement . ?statement ps:P28 wd:Q924 . ?statement pq:P4100 ?total_reserves . } limit 100
# 44
# SELECT ?result WHERE { wd:Q3962734 wdt:P3840 ?slope_rating . FILTER(?slope_rating = 149) BIND(xsd:boolean(?slope_rating = 149) as ?result) } limit 100
# 45
# SELECT ?density WHERE { ?compound rdfs:label "Hydrogen peroxide"@en . ?compound wdt:P2054 ?density . ?compound wdt:P6879 ?temperature . FILTER(?temperature = 20.0) } limit 100
# 46
# SELECT ?architecture_firm WHERE { Q1050571 wdt:P276 wd:Q16845909 . Q1050571 wdt:P84 ?architecture_firm . } limit 100
# Request failed with status code 400
# Failed query number 46
# 47
# SELECT ?meansseason WHERE { ?meansseason wdt:P1350 ?start_date . FILTER(MONTH(?start_date) = 2) } limit 100
# Request failed with status code 500
# Failed query number 47
# 48
# SELECT ?winner WHERE { ?event wdt:P166 ?prize . ?event wdt:P1346 ?winner . ?prize rdfs:label "${prize_awarded}"@en . ?winner rdfs:label ?winner_label . FILTER(LCASE(?winner_label) = LCASE("${champ}")) } limit 100
# 49
# SELECT ?ammunition WHERE { ?weapon wdt:P366 wd:Q48967047 . ?weapon wdt:P739 ?ammunition . } limit 100
# 50
# SELECT ?breedLabel WHERE { ?breed wdt:P31 wd:Q15304597 . ?breed rdfs:label ?breedLabel . FILTER(lang(?breedLabel) = 'en') . FILTER(STRSTARTS(LCASE(?breedLabel), 'z')) } limit 100
# 51
# SELECT ?coalitionLabel WHERE { wd:Q501758 wdt:P102 ?coalition . ?coalition wdt:p-InstanceOf wd:Q124964 . SERVICE wikibase:label { bd:serviceParam wikibase:language 'en' . } } limit 100
# 52
# SELECT ?brother_in_law WHERE { ?writer wdt:P50 ?quran . ?brother_in_law wdt:P3373 ?sibling_of_writer . ?sibling_of_writer wdt:P26 ?spouse_of_sibling . ?spouse_of_sibling wdt:P50 ?quran . } limit 100
# 53
# SELECT ?place_id WHERE { ?place wdt:P31 wd:Q107569809 . ?place rdfs:label "Auckland"@en . ?place wdt:P7471 ?place_id . } limit 100
# 54
# SELECT ?result WHERE { ?painting rdfs:label "Grade Odalisque"@en . ?painting wdt:P180 ?depiction . ?depiction rdfs:label ?result . FILTER(STRENDS(str(?result), "DRTL")) } limit 100
# 55
# SELECT ?empireLabel WHERE { ?empire wdt:P31 wd:Q7275 . ?empire rdfs:label ?empireLabel . FILTER(LANG(?empireLabel) = 'en') FILTER(CONTAINS(LCASE(?empireLabel), 'british')) } limit 100
# 56
# SELECT ?instance WHERE { ?instance wdt:P31 wd:Q8457 . ?instance wdt:P569 ?date_of_birth . FILTER(?date_of_birth = xsd:dateTime('1489-08-01T00:00:00Z')) } limit 100
# 57
# SELECT Q37226 WHERE { Q37226 Q334384 Q6533159 . Q37226 Q12737077 wd:q-Teacher } limit 100
# Request failed with status code 400
# Failed query number 57
# 58
# SELECT ?sandre_id WHERE { ?river rdfs:label "Rhine"@en . ?river wdt:P1717 ?sandre_id . } limit 100
# 59
# SELECT ?date WHERE { ?person rdfs:label "Kylie Minogue"@en . ?award rdfs:label "Gold Logie Award for Most Popular Personality on Australian Television"@en . ?person wdt:P166 ?award . ?person wdt:P585 ?date . } limit 100
# 60
# SELECT ?business WHERE { ?person rdfs:label "Alexander McQueen"@en . ?person wdt:P106 ?business . } limit 100
# 61
# SELECT ?deityLabel WHERE { wd:Q34201 wdt:Q21503252 wd:Q22989102 . wd:Q34201 wdt:Q31184 ?sibling . ?sibling wdt:Q21503252 wd:Q22989102 . ?sibling rdfs:label ?deityLabel . FILTER(lang(?deityLabel) = 'en') FILTER(CONTAINS(?deityLabel, 'Poseidon')) } limit 100
# 62
# SELECT ?organizer WHERE { ?game wdt:P1476 'Ultima III: Exodus' . ?game wdt:P664 ?organizer . } limit 100
# 63
# SELECT ?lead_actor WHERE { ?movie wdt:P31 wd:Q11424 . ?movie wdt:P161 ?lead_actor . ?movie rdfs:label "Deadpool"@en . ?lead_actor rdfs:label ?lead_actor_label . FILTER(LANG(?lead_actor_label) = "en") } limit 100
# 64
# SELECT ?workLabel WHERE { ?work wdt:P1441 wd:Q2709 . ?work wdt:P31/wdt:P279* wd:Q2188189 . SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } } limit 100
# 65
# SELECT ?awardLabel WHERE { ?person rdfs:label "John de Mol"@en . ?person wdt:P166 ?award . ?award wdt:P585 ?date . FILTER(YEAR(?date) = 2011) SERVICE wikibase:label { bd:serviceParam wikibase:language "en" } } limit 100
# 66
# SELECT ?result WHERE { wd:Q262 wdt:Q285897 ?total_fertility_rate . FILTER(?total_fertility_rate > 3.4284) BIND(xsd:boolean(?total_fertility_rate > 3.4284) as ?result) } limit 100
# 67
# SELECT ?time WHERE { ?water wdt:P2067 ?triple_point . ?water wdt:P2073 ?pressure . ?water wdt:P2072 ?temperature . FILTER(?pressure = ?triple_point_pressure && ?temperature = ?triple_point_temperature) ?water wdt:P585 ?time . } limit 100
# 68
# SELECT ?phenomenonLabel WHERE { ?phenomenon wdt:P31/wdt:P279* Q93398212 . ?phenomenon Q18127 ?phenomenonLabel . FILTER(LANG(?phenomenonLabel) = 'en') FILTER(CONTAINS(LCASE(?phenomenonLabel), 'surface')) } limit 100
# Request failed with status code 400
# Failed query number 68
# 69
# SELECT ?place WHERE { wd:Q7747 wdt:P551 ?place . } limit 100
# 70
# SELECT ?municipality WHERE { ?eu wdt:P159 ?headquarters . ?headquarters wdt:P131 ?municipality . ?municipality wdt:p-country Q31 } limit 100
# Request failed with status code 400
# Failed query number 70
# 71
# SELECT ?result WHERE { ?result wdt:P652 wd:Q449506 . ?result wdt:P1843 'Domestic Goat' } limit 100
# 72
# SELECT ?result WHERE { wd: wdt:P706 ?result . } limit 100
# 73
# SELECT ?battleLabel WHERE { ?battle wdt:P4791 wd:Q216124 . SERVICE wikibase:label { bd:serviceParam wikibase:language 'en' . } } limit 100
# 74
# SELECT ?temperature ?state_of_matter WHERE { wd:Q7892 wdt:Q11579 ?temperature . wd:Q7892 wdt:Q108807274 ?state_of_matter . FILTER(?temperature = 647.096) FILTER(?state_of_matter = wd:Q7269030) } limit 100
# 75
# SELECT ?point_in_time WHERE { ?syria Q15715409 ?population . ?population Q24533326 ?population_amount . ?population_amount Q2360980 ?amount . ?population_amount wikibase:quantityUnit Q5 . ?population_amount Q186408 ?point_in_time_statement . ?point_in_time_statement ps:P585 ?point_in_time . FILTER(?amount = 8.08815e+06) } limit 100
# Request failed with status code 400
# Failed query number 75
# 76
# SELECT ?result WHERE { wd:Q39809 wdt: ?involvement1 . ?involvement1 (wdt:p-SubclassOf)* wd:Q5936993 . ?involvement2 (wdt:p-SubclassOf)* wd:Q207822 . wd:Q39809 wdt: ?involvement2 . BIND(xsd:boolean(EXISTS {?involvement1 (wdt:p-SubclassOf)* wd:Q5936993 . ?involvement2 (wdt:p-SubclassOf)* wd:Q207822}) as ?result) } limit 100
# 77
# SELECT ?stage_race (COUNT(?event) AS ?event_count) WHERE { ?stage_race wdt:P31 wd:Q207694 . ?stage_race wdt:P793 ?event . } GROUP BY ?stage_race ORDER BY DESC(?event_count) LIMIT 1
# 78
# SELECT ?municipality_key WHERE { ?municipality wdt:P439 ?municipality_key . ?municipality rdfs:label 'Klagenfurt'@en . ?municipality wdt:P17 wd:Q40 . } limit 100
# 79
# SELECT ?regionLabel WHERE { ?region wdt:Q21503252 wd:Q17269 . ?region Q18127 ?regionLabel . FILTER(lang(?regionLabel) = 'en') FILTER(CONTAINS(LCASE(?regionLabel), 'xinjiang')) FILTER(?region wdt:Q83440 wd:Q985488) } limit 100
# Request failed with status code 400
# Failed query number 79
# 80
# SELECT ?race ?time WHERE { ?race wdt:P1346 Q12044712 . ?race wdt:P2781 ?time . ?race wdt:P2094 ?competition . ?competition rdfs:label "Velká pardubická"@en . } ORDER BY ASC(?time) LIMIT 1
# Request failed with status code 400
# Failed query number 80
# 81
# SELECT ?author ?award WHERE { ?work wdt:P1476 "Watchmen" . ?work wdt:P50 ?author . ?author wdt:P166 ?award . } limit 100
# 82
#  limit 100
# Request failed with status code 400
# Failed query number 82
# 83
# SELECT ?bookLabel WHERE { ?book wdt:P31 wd:Q571 . ?book wdt:P407 wd:Q143 . ?book rdfs:label ?bookLabel . FILTER(LANG(?bookLabel) = 'en') } LIMIT 1
# 84
# SELECT ?general_managerLabel WHERE { wd:Q109255 wdt:P505 ?general_manager . SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } } limit 100
# 85
# SELECT ?film_name WHERE { ?film wdt:P31 wd:Q11424 . ?film wdt:P577 ?date . ?film wdt:P2142 ?rating . ?film wdt:P2130 ?cost . FILTER(?rating = 'FSK 12'@en) FILTER(?date < NOW()) BIND(?cost as ?cost_in_euros) FILTER(?cost_in_euros = (SELECT MAX(?cost2) WHERE { ?film2 wdt:P2142 ?rating . ?film2 wdt:P2130 ?cost2 . FILTER(?rating = 'FSK 12'@en) })) ?film rdfs:label ?film_name . FILTER(LANG(?film_name) = 'en') } limit 100
# Request failed with status code 400
# Failed query number 85
# 86
# SELECT (COUNT(?item) as ?count) WHERE { ?item rdfs:label ?label . FILTER(CONTAINS(LCASE(?label), 'daniel dennett')) . ?item wdt:P683 ?interest } limit 100
# 87
# SELECT ?Q34578231 WHERE { ?event Q186408 ?date . ?event wdt:P131 Q23154 . ?event Q21503252 ?type . FILTER(YEAR(?date) = 1996) FILTER(CONTAINS(LCASE(?Q1542343), 'event')) SERVICE wikibase:label { bd:serviceParam wikibase:language 'en' . } } limit 100
# Request failed with status code 400
# Failed query number 87
# 88
# SELECT ?source WHERE { wd:Q584 wdt:P248 ?source . } limit 100
# 89
#  limit 100
# Request failed with status code 400
# Failed query number 89
# 90
# SELECT ?tower WHERE { ?tower wdt:P180 wd:Q41213 . ?tower rdfs:label ?label . FILTER(CONTAINS(LCASE(?label), 'babel') && LANG(?label) = 'en') } limit 100
# 91
# SELECT ?position ?election_date ?reason_for_leaving WHERE { wd:Q128985 wdt:P39 ?position_statement . ?position_statement ps:P39 ?position . ?position_statement pq:P1614 wd:Q21084451 . OPTIONAL { ?position_statement pq:P2715 ?election . ?election Q186408 ?election_date . } OPTIONAL { ?position_statement pq:P10441 ?reason . ?reason rdfs:label ?reason_for_leaving . FILTER(LANG(?reason_for_leaving) = 'en') } } limit 100
# Request failed with status code 400
# Failed query number 91
# 92
# SELECT ?result WHERE { wd:Q430024 wdt:P3737 ?max_wavelength . FILTER(?max_wavelength = 700) BIND(xsd:boolean(?max_wavelength = 700) as ?result) } limit 100
# 93
# SELECT ?birth_location WHERE { wd:Q62835 wdt:Q1322263 ?birth_location . FILTER(?birth_location = wd:) } limit 100
# 94
# SELECT ?nobel_laureate WHERE { ?nobel_laureate wdt:P31 wd:Q5 . ?nobel_laureate wdt:P166 wd:Q7191 . ?nobel_laureate wdt:P802 wd:Q8998 . ?nobel_laureate wdt:P166 ?prize . ?prize wdt:P31 wd:Q19020 . ?prize wdt:P585 ?date . FILTER(?date > "YEAR-01-01T00:00:00Z"^^xsd:dateTime) } ORDER BY ASC(?date) LIMIT 1
# 95
# SELECT ?date WHERE { ?person wdt:P166 ?award . ?award wdt:P166Recipient ?recipient . ?recipient rdfs:label "Eiji Toyoda"@en . ?award wdt:P166ForWork ?work . ?work rdfs:label "Order of Prince Henry"@en . ?award wdt:P166Date ?date . } limit 100
# 96
# SELECT ?start_date ?end_date WHERE { wd:Q181 wdt: ?employment_history . ?employment_history ps:P108 [rdfs:label "Bomis"@en] ; ps:P580 ?start_date . OPTIONAL { ?employment_history ps:P582 ?end_date } } limit 100
# 97
# SELECT ?author WHERE { wd:Q57085 wdt:P2680 ?book . ?book wdt:P50 ?author . } limit 100
# 98
# SELECT ?person WHERE { ?org wdt:P625 wd:Q60 . ?person wdt:P108 ?org . ?person rdfs:label ?person_label . FILTER(LANG(?person_label) = 'en' && ?person_label = 'Michelle Wolf') } limit 100
# 99
# SELECT ?unit_of_measurement WHERE { ?unit_of_measurement wdt:P2370 ?symbol . FILTER(regex(?symbol, '^visus', 'i')) } limit 100
# 100
# SELECT ?publication_date WHERE { ?itunes Q27860817 "12.7.5" . ?itunes Q1361758 ?publication_date . } limit 100
# Request failed with status code 400
# Failed query number 100
# 101
# SELECT ?languageLabel WHERE { ?language wdt:P287 wd:Q45575 . ?language wdt:P3966 wd:Q223335 . SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } } limit 100
# 102
# SELECT ?role WHERE { ?mickey_mouse wdt:P50 ?ben_sharpsteen . ?mickey_mouse wdt:P106 ?role . FILTER(?mickey_mouse = Q11934) FILTER(?ben_sharpsteen = Q2549739) } limit 100
# Request failed with status code 400
# Failed query number 102
# 103
# SELECT ?stock_exchange WHERE { ?company rdfs:label "Tencent"@en . ?company wdt:P249 "0700" . ?company wdt:P414 ?stock_exchange . } limit 100
# 104
# SELECT ?head_of_state_label ?office_label WHERE { wd:Q15180 wdt:P1906 ?head_of_state . ?head_of_state wdt:P106 ?office . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . ?head_of_state rdfs:label ?head_of_state_label . ?office rdfs:label ?office_label . } } limit 100
# 105
# SELECT ?awardLabel WHERE { wd:Q229040 wdt:P710/wdt:Q21096945 ?award . ?award rdfs:label ?awardLabel . FILTER(LANG(?awardLabel) = 'en') } limit 100
# 106
# SELECT ?parent_organization WHERE { wd:Q7801 wdt:P749 ?parent_organization . } limit 100
# 107
# SELECT ?beginning WHERE { wd:Q11194 wdt:P1350 ?beginning . } limit 100
# 108
# SELECT ?eventLabel WHERE { ?event wdt:P710 wd:Q320 . ?event wdt:P813 ?date . FILTER(?date >= "1978-06-01T00:00:00Z"^^xsd:dateTime && ?date < "1978-06-02T00:00:00Z"^^xsd:dateTime) . ?event wdt:P800 ?significance . FILTER(?significance = wd:Q24628935) . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# 109
# SELECT ?solubility WHERE { ?Q422709 wdt: ?solubility . FILTER(lang(?solubility) = 'en') } limit 100
# 110
# SELECT ?stateLabel WHERE { wd:Q143762 wdt:P206 ?state . ?state wdt:P206 wd:Q143762 . ?state rdfs:label ?stateLabel . FILTER(lang(?stateLabel) = 'en') } LIMIT 5
# 111
#  limit 100
# Request failed with status code 400
# Failed query number 111
# 112
# SELECT ?languageLabel WHERE { wd: wdt:P103 ?language . SERVICE wikibase:label { bd:serviceParam wikibase:language 'en'. } } limit 100
# 113
# SELECT ?ionization_energy WHERE { ?nicotine wdt:P2260 ?ionization_energy . FILTER(lang(?ionization_energy) = 'en') } limit 100
# 114
# SELECT ?result WHERE { wd:Q12204 wdt:P1193 ?prevalence . BIND(xsd:boolean(?prevalence) as ?result) } limit 100
# 115
# SELECT ?creator WHERE { ?work wdt:P31 wd:Q11424 . ?work rdfs:label "Star Trek Into Darkness"@{language} . ?work wdt:P50 ?creator . ?creator rdfs:label ?creator_label . FILTER(LCASE(?creator_label) = LCASE("{creators}")) } limit 100
# Request failed with status code 400
# Failed query number 115
# 116
# SELECT ?spouse ?divorce_date WHERE { ?person wdt:P26 ?spouse_statement . ?spouse_statement ps:P26 wd:Q11617 . OPTIONAL { ?spouse_statement pq:p-EndTime ?divorce_date . } } limit 100
# 117
# SELECT ?result WHERE { wd:Q78474 wdt:P1532 ?nationality . ?nationality rdfs:label "{{nationality}}"@en . wd:Q78474 wdt:P466 ?inhabitant . ?inhabitant rdfs:label ?result . FILTER(LANG(?result) = "en") } limit 100
# 118
# SELECT ?buildingLabel WHERE { wd:Q49088 wdt:P1416 ?building . ?building rdfs:label ?buildingLabel . FILTER(LANG(?buildingLabel) = 'en') } limit 100
# 119
# SELECT Q484170 WHERE { ?commune Q18954751 Q142 . ?commune Q15715409 ?population . ?commune Q941023 Q6655 . FILTER(?population = Q57275539) SERVICE wikibase:label { bd:serviceParam wikibase:language "en" } } limit 100
# Request failed with status code 400
# Failed query number 119
# 120
# SELECT ?district WHERE { ?district wdt:P131 wd:Q515 . { SELECT (MAX(?count) as ?max_count) WHERE { ?house wdt:P131 wd:Q515 . ?house wdt:P31 wd:Q3947 . ?district wdt:P527 ?house . BIND(COUNT(?house) as ?count) } } . ?district wdt:P527 ?house . ?house wdt:P31 wd:Q3947 . { SELECT (MAX(?count) as ?max_count) WHERE { ?house wdt:P131 wd:Q515 . ?house wdt:P31 wd:Q3947 . ?district wdt:P527 ?house . BIND(COUNT(?house) as ?count) } } FILTER(?count = ?max_count) } limit 100
# 121
# SELECT ?occupation ?field_of_work ?worked_in_Dublin_Castle WHERE { ?person rdfs:label "Bram Stoker"@en . ?person wdt:P106 ?occupation . ?person wdt:P101 ?field_of_work . OPTIONAL { ?person wdt:P937 wd:Q295978 } BIND(xsd:boolean(?person = wd:Q1289 && ?worked_in_Dublin_Castle = wd:Q295978) as ?worked_in_Dublin_Castle) } limit 100
# 122
# SELECT (COUNT(?season) as ?result) WHERE { ?season wdt:P118 wd:Q175762 . } limit 100
# 123
# SELECT ?place_of_residence WHERE { ?person rdfs:label "Wangari Maathai"@en . ?person wdt:P551 ?place_of_residence . ?place_of_residence wdt:P1279 ?inflation_rate . FILTER(?inflation_rate = 2.9) } limit 100
# 124
# SELECT ?child WHERE { ?child wdt:P22 Q19604 . ?child wdt:P22 Q273616 } limit 100
# Request failed with status code 400
# Failed query number 124
# 125
# SELECT ?beverageLabel WHERE { ?beverage wdt:P31 wd:Q154 and ?beverage rdfs:label ?beverageLabel . FILTER(LANG(?beverageLabel) = 'en' && CONTAINS(LCASE(?beverageLabel), 'rum')) } LIMIT 1
# Request failed with status code 400
# Failed query number 125
# 126
# SELECT (COUNT(?terminus) as ?count) WHERE { ?terminus wdt:P559 Q1741 } limit 100
# Request failed with status code 400
# Failed query number 126
# 127
# SELECT ?itemLabel WHERE { ?item wdt:P131 wd: . ?item wdt:P150 wd:Q133642 . SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } } limit 100
# 128
# SELECT ?sister_city WHERE { wd:Q92161 wdt:P190 ?sister_city . ?sister_city wdt:P580 ?start_time . FILTER(?start_time <= "1992-08-25T00:00:00Z"^^xsd:dateTime) OPTIONAL { ?sister_city wdt:P582 ?end_time . FILTER(?end_time >= "1992-08-25T00:00:00Z"^^xsd:dateTime) } } limit 100
# 129
# SELECT (COUNT(DISTINCT ?water_body) as ?count) WHERE { wd:Q199551 wdt:P2789 ?water_body . FILTER(?water_body IN (wd:Q4022, wd:Q23397)) } limit 100
# 130
# SELECT ?soil_type WHERE { ?soil_type rdfs:label ?label . FILTER(CONTAINS(LCASE(?label), 'vertisol') && LANG(?label) = 'en') } limit 100
# Request failed with status code 500
# Failed query number 130
# 131
# SELECT ?id WHERE { ?athlete wdt:P735 "Lizzy Yarnold" . ?athlete wdt:P1447 ?id . ?athlete wdt:P856 ?website . FILTER(STRSTARTS(?website, "http://www.the-sports.org/")) } limit 100
# 132
# SELECT ?award_received WHERE { ?person rdfs:label "Justin Timberlake"@en . ?person wdt:P166 ?award . ?award wdt:P166Recipient ?person . ?award wdt:P166Date ?date . FILTER(?date >= "2007-01-01T00:00:00Z"^^xsd:dateTime && ?date < "2008-01-01T00:00:00Z"^^xsd:dateTime) ?award rdfs:label "P166"@en . } limit 100
# 133
# SELECT ?conceptLabel WHERE { ?concept wdt:P279* Q23847174 . ?concept Q18127 ?conceptLabel . FILTER(lang(?conceptLabel) = 'en') FILTER(STRENDS(LCASE(?conceptLabel), 't')) } limit 100
# Request failed with status code 400
# Failed query number 133
# 134
# SELECT ?result WHERE { wd:Q1049487 wdt:P2145 ?explosive_energy . FILTER(?explosive_energy < 52.8) BIND(xsd:boolean(?explosive_energy < 52.8) as ?result) } limit 100
# 135
# SELECT ?date_of_birth WHERE { ?child wdt:P22 wd:Q206191 . ?child wdt:P569 ?date_of_birth . } limit 100
# 136
# SELECT ?result WHERE { wd:Q742408 wdt:P2665 ?abv . FILTER(?abv < 30.4) BIND(xsd:boolean(?abv < 30.4) as ?result) } limit 100
# 137
# SELECT ?cityLabel WHERE { ?city Q21503252 Q748149 . ?city Q18127 ?cityLabel . FILTER(lang(?cityLabel) = 'en') FILTER(STRSTARTS(?cityLabel, 'Ürümqi')) } limit 100
# Request failed with status code 400
# Failed query number 137
# 138
# SELECT ?ceremony WHERE { ?ceremony Q18127 ?label . FILTER(CONTAINS(LCASE(?label), 'umhlanga') && LANG(?label) = 'en') } limit 100
# Request failed with status code 400
# Failed query number 138
# 139
# SELECT ?result WHERE { ?Q80071 ?Q46343203 ?Q5431887 . ?Q46343203 rdfs:label "played as"@en . BIND(str(?Q46343203) as ?result) } limit 100
# 140
# SELECT ?runtime WHERE { ?game wdt:P735 "League of Legends" . ?game wdt:P747 ?edition . ?edition wdt:P2047 ?runtime . } limit 100
# 141
# SELECT ?name WHERE { ?amsterdam wdt: ?coat_of_arms . ?coat_of_arms rdfs:label ?name . FILTER(LANG(?name) = 'en') } limit 100
# 142
# SELECT ?sauce WHERE { ?sauce wdt:P495 Q884 . } limit 100
# Request failed with status code 400
# Failed query number 142
# 143
# SELECT (COUNT(DISTINCT ?depositor) as ?count) WHERE { ?depositor wdt: wd:Q81066 } limit 100
# 144
# SELECT ?electric_charge WHERE { wd:Q216121 wdt:P2200 ?electric_charge . } limit 100
# 145
# SELECT ?giver WHERE { ?person wdt:P608 ?isShownBy . ?person wdt:P144 ?basedOn . ?person wdt:P7904 ?giver . FILTER(?isShownBy = <PLACEHOLDER-IS-SHOWN-BY> && ?basedOn = <PLACEHOLDER-BASED-ON> && ?person = <PLACEHOLDER-PERSON>) } limit 100
# 146
# SELECT ?result WHERE { wd:Q29619735 wdt:P6257 ?longitude . BIND(xsd:float(?longitude) as ?result) } limit 100
# 147
# SELECT ?team WHERE { ?team Q21503252 Q26887310 . ?team rdfs:label ?label . FILTER(CONTAINS(LCASE(?label), 'team') && LANG(?label) = 'en') } limit 100
# Request failed with status code 400
# Failed query number 147
# 148
# SELECT ?notable_work_label ?publisher_label WHERE { wd:Q49081 wdt:P800 ?notable_work . ?notable_work wdt:publisher ?publisher . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . ?notable_work rdfs:label ?notable_work_label . ?publisher rdfs:label ?publisher_label . } } ORDER BY DESC(?notable_workLabel) LIMIT 1
# 149
# SELECT ?code WHERE { ?country Q21503252 Q83440 . ?country Q18127 "Democratic Republic of Congo"@en . ?country  ?code . } limit 100
# Request failed with status code 400
# Failed query number 149
# 150
# SELECT ?id WHERE { ?person wdt:P2943 ?id . ?person rdfs:label "Yuri Gagarin"@en . } limit 100
# 151
# SELECT ?result WHERE { wd:Q744 wdt:P2386 ?diameter . FILTER(?diameter = 0.807) BIND(xsd:boolean(?diameter = 0.807) as ?result) } limit 100
# 152
# SELECT ?result WHERE { wd:Q50334841 p:P569 ?birthdate_statement . ?birthdate_statement ps:P569 ?birthdate . BIND(xsd:integer(year(now()) - year(?birthdate)) as ?age) FILTER(?age > 52) BIND(xsd:boolean(?age > 52) as ?result) } limit 100
# 153
# SELECT ?date WHERE { wd:Q23564 wdt:P580 ?event . ?event wdt:P31 wd:Q779011 . ?event wdt:P580 ?date . } limit 100
# 154
# SELECT ?result WHERE { wd:Q14982 wdt:P2116 ?enthalpy . FILTER(?enthalpy = 37400) BIND(xsd:boolean(?enthalpy = 37400) as ?result) } limit 100
# 155
# SELECT ?award WHERE { wd:Q615944 wdt:P166 ?award . } limit 100
# 156
# SELECT ?itemLabel WHERE { wd:Q127 wdt:Q98775491 ?item . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# 157
# SELECT (COUNT(?archive) as ?count) WHERE { ?archive wdt:P6241 wd:Q11641 . } limit 100
# 158
# SELECT ?narrative_location WHERE { ?s wdt:P31 wd:Q9441 . ?s wdt:P840 ?narrative_location . FILTER(LANG(?narrative_location) = 'en') } limit 100
# 159
# SELECT ?place WHERE { ?place Q96623327 ?location . ?location Q96623327 ?coord . FILTER(?coord < "Point(2.4697602 48.8363848)"^^geo:wktLiteral) ?place wdt:P1435 Q205875 . } limit 100
# Request failed with status code 400
# Failed query number 159
# 160
# SELECT ?operation WHERE { ?operation wdt:P31 Q645883 . ?operation Q18127 ?label . FILTER(lang(?label) = 'en' && STRSTARTS(LCASE(?label), 'o')) } limit 100
# Request failed with status code 400
# Failed query number 160
# 161
# SELECT ?result WHERE { wd:Q3535481 wdt:P1357 ?matches_drawn . FILTER(?matches_drawn = 0) BIND(xsd:boolean(?matches_drawn = 0) as ?result) } limit 100
# 162
# SELECT ?mother ?husband WHERE { ?person rdfs:label "Candice Bergen"@en . ?person wdt:P25 ?mother . ?person wdt:P26 ?husband . } limit 100
# 163
# SELECT ?language WHERE { ?film wdt:P1705 ?language . ?film wdt:P161 wd:Q78469 . ?language wdt:P11053 wd:Q51929517 } limit 100
# 164
# SELECT ?result WHERE { wd:Q56746601 wdt:P4448 ?cash_back . FILTER(?cash_back = 5) BIND(xsd:boolean(?cash_back = 5) as ?result) } limit 100
# 165
# SELECT ?Q22006653 WHERE { ?Q188784 Q22006653 ?Q22006653 . } limit 100
# Request failed with status code 400
# Failed query number 165
# 166
# SELECT ?use WHERE { ?use wdt:P741 Q369225 . } limit 100
# Request failed with status code 400
# Failed query number 166
# 167
# SELECT ?population WHERE { ?city rdfs:label "Aden"@en . ?city wdt:P1082 ?population . ?city wdt:Q21503252 wd:Q515 } limit 100
# 168
# SELECT ?spouse WHERE { wd:Q295855 wdt:P26 ?spouse_statement . ?spouse_statement ps:P26 ?spouse . ?spouse_statement pq:P580 ?start_time . FILTER(?start_time = "2006-01-01T00:00:00Z"^^xsd:dateTime) } limit 100
# 169
# SELECT ?count WHERE { wd:Q227 wdt:P500 ?exclave . ?exclave wdt:p-country wd:Q34266 .  ?exclave wdt:P1545 ?count . } limit 100
# 170
# SELECT ?equity WHERE { ?company rdfs:label "Micron Technology"@en . ?company wdt:P2137 ?equity . } limit 100
# 171
# SELECT ?result WHERE { wd:Q395274 wdt:P19 ?place_of_birth . ?place_of_birth rdfs:label ?place_of_birth_label . FILTER(LCASE(?place_of_birth_label) = LCASE('Edmonton')) BIND(xsd:boolean(LCASE(?place_of_birth_label) = LCASE('Edmonton')) as ?result) } limit 100
# 172
# SELECT ?architect ?heritage_designation WHERE { wd:Q62408 wdt:P84 ?architect . wd:Q62408 wdt:P1435 ?heritage_designation . } limit 100
# 173
# SELECT ?result WHERE { wd:Q29565582 wdt:P3253 ?opt_temp . FILTER(?opt_temp > 24.0) BIND(xsd:boolean(?opt_temp > 24.0) as ?result) } limit 100
# 174
# SELECT Q83440 WHERE { Q83440 wdt: Q12444025 } limit 100
# Request failed with status code 400
# Failed query number 174
# 175
# SELECT ?elementLabel WHERE { ?element wdt:P31 wd:Q11344 . ?element wdt:P137 wd:Q21 . ?element wdt:P136 wd:Q175141 . ?element wdt:P1086 ?melting_point . FILTER(?melting_point < 300 && ?melting_point > 0) . ?element rdfs:label ?elementLabel . FILTER(lang(?elementLabel) = 'en' && regex(?elementLabel, '^O', 'i')) } LIMIT 1
# 176
# SELECT ?result WHERE { ?player wdt:P647 ?draft_pick . ?player rdfs:label 'Sidney Crosby'@en . ?draft_pick rdfs:label ?result . } limit 100
# 177
# SELECT (COUNT(?rank) as ?count) WHERE { ?rank wdt:P31 wd:Q186088 . } limit 100
# 178
# SELECT Q51929074 WHERE { Q51929074 Q48282 Q45936 . } limit 100
# Request failed with status code 400
# Failed query number 178
# 179
# SELECT ?position ?election_date ?position_53rd_parliament WHERE { wd:Q193630 p:position/ps:position ?position . wd:Q193630 p:P39 ?position_held . ?position_held ps:P39 ?position . ?position_held pq:P580 ?election_date . FILTER(YEAR(?election_date) > 0) OPTIONAL { ?position_held pq:P4100 ?position_53rd_parliament } } limit 100
# 180
# SELECT ?Q3543591 WHERE { ?Q3543591 wdt:P22 wd:Q17853991 . ?Q3543591 wdt:Q21503252 wd:Q5 } limit 100
# 181
# SELECT ?award ?time WHERE { wd:Q359552 wdt:P1411 ?award_statement . ?award_statement ps:P1411 ?award . ?award_statement pq:P585 ?time . } limit 100
# 182
# SELECT ?date WHERE { ?person rdfs:label "John X"@en . ?person wdt: ?date . ?person p:P1329 ?statement . ?statement ps:P1329 ?date . ?statement pq:P459 ?circumstances . ?circumstances rdfs:label "sourcing circumstances"@en . } limit 100
# 183
#  limit 100
# Request failed with status code 400
# Failed query number 183
# 184
# SELECT ?result WHERE { wd:Q13371 wdt:P2555 ?fee . FILTER(?fee < 90) BIND(xsd:boolean(?fee < 90) as ?result) } limit 100
# 185
# SELECT ?person_id WHERE { ?person wdt:P31 wd:Q51929074 . ?person wdt:P5450 ?person_id . ?person rdfs:label "Carl Rogers"@en . FILTER(LANG(?person_id) = "en") } limit 100
# 186
# SELECT ?personLabel WHERE { wd:Q128446 wdt:P634 ?person . SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } } limit 100
# 187
# SELECT ?regionLabel WHERE { ?region wdt:P31 Q17269. ?region wdt:P17 Q985488. ?region Q18127 ?regionLabel. FILTER(lang(?regionLabel) = 'en'). FILTER(STRSTARTS(LCASE(?regionLabel), 'x')) } limit 100
# Request failed with status code 400
# Failed query number 187
# 188
# SELECT ?timezoneLabel WHERE { wd:Q23482 wdt:P421 ?timezone . ?timezone rdfs:label ?timezoneLabel . FILTER(LANG(?timezoneLabel) = 'en') } limit 100
# 189
# SELECT ?awardLabel WHERE { wd:Q132695 wdt:P166 ?award . ?award wdt:P1706 wd:Q131326 . SERVICE wikibase:label { bd:serviceParam wikibase:language 'en'. } } limit 100
# 190
# SELECT ?Q115448723 WHERE { ?Q44613 wdt:P140 wd:Q60995 . ?Q44613 wdt:P159 ?Q115448723 . } limit 100
# 191
# SELECT ?player_id WHERE { ?person rdfs:label "Sergey Lomanov"@en . ?person wdt:P4831 ?player_id . } limit 100
# 192
# SELECT ?writer WHERE { ?book wdt:P31 wd:Q21145331 . ?book wdt:P50 ?writer . FILTER NOT EXISTS { ?book wdt:P747 ?edition . ?edition wdt:P407 ?language . FILTER(?language = wd:Q1860) } } limit 100
# 193
# SELECT ?female_name WHERE { ?female wdt:P21 wd:Q6581072 . ?discovery wdt:P61 ?female . ?discovery wdt:P527 wd:Q132959 . ?discovery rdfs:label ?discovery_label . FILTER(LANG(?discovery_label) = 'en' && LCASE(?discovery_label) = 'horsehead nebula') ?female rdfs:label ?female_name . FILTER(LANG(?female_name) = 'en') } limit 100
# 194
# SELECT ?fruitLabel WHERE { ?fruit wdt:P31 wd:Q3314483 . ?fruit wdt:P105 wd:Q1364 . ?fruit rdfs:label ?fruitLabel . FILTER(LANG(?fruitLabel) = 'en') FILTER(STRSTARTS(LCASE(?fruitLabel), 'w')) } limit 100
# 195
# SELECT ?conflict WHERE { wd:Q117693 wdt:P180 ?conflict . ?conflict wdt:P31/wdt:P279* wd:Q350604 . } limit 100
# 196
# SELECT ?unary_operation_notation WHERE { ?unary_operation_notation wdt:P6604 wd: . ?unary_operation_notation wdt:p-Notation ?notation . FILTER(STRSTARTS(?notation, 'i')) } limit 100
# 197
# SELECT Q34640765 WHERE { ?Q96739634 Q21032523 ?disease . ?disease wdt:P31 Q12136 . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# Request failed with status code 400
# Failed query number 197
# 198
# SELECT ?categoryLabel WHERE { wd:Q1262738 wdt:Q7020596 ?category . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# 199
# SELECT ?inflation_rate WHERE { wd:Q717 wdt:Q186408 ?date . ?event wdt:Q186408 ?date . ?event wdt:Q21503252 wd:Q273508 . ?event wdt:Q35186749 ?inflation_rate . FILTER(YEAR(?date) = 1996) } limit 100
# 200
# SELECT ?date WHERE { ?nomination Q107368869 ?actor . ?nomination Q7048605 Q19020 . ?nomination Q21096945 Q19020 . ?nomination Q186408 ?date . FILTER(regex(str(?actor), 'Vittorio De Sica', 'i')) } limit 100
# Request failed with status code 400
# Failed query number 200
# 201
# SELECT ?aunamendi_id WHERE { ?person rdfs:label "Miguel López de Legazpi"@en . ?person wdt:P3218 ?aunamendi_id } limit 100
# 202
# SELECT ?timezoneLabel WHERE { wd:Q7170 wdt:P20 ?placeOfDeath . ?placeOfDeath wdt:P421 ?timezone . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . ?timezone rdfs:label ?timezoneLabel . } } limit 100
# 203
# SELECT ?result WHERE { wd:Q83164 wdt:P1830 wd:Q185103 . wd:Q83164 wdt:P1830 wd:Q5001294 . BIND(xsd:boolean(EXISTS { wd:Q83164 wdt:P1830 wd:Q185103 . wd:Q83164 wdt:P1830 wd:Q5001294 . }) AS ?result) } limit 100
# 204
# SELECT ?isni WHERE { ?person rdfs:label "Marit Bjørgen"@en . ?person wdt:P213 ?isni . } limit 100
# 205
# SELECT ?total_fertility_rate WHERE { ?country wdt:Q21503252 wd:Q3624078 . ?country rdfs:label "Trinidad and Tobago"@en . ?country wdt:P4841 ?total_fertility_rate . ?country wdt:P459 ?determination_method . ?determination_method rdfs:label "Estimation process"@en . } limit 100
# 206
# SELECT ?church WHERE { ?church wdt:P131 ?parish . ?parish rdfs:label "Krukengrund"@en . ?church wdt:P17 ?place . ?place wdt:P131 ?parish . } limit 100
# 207
# SELECT ?nomination WHERE { ?book wdt:P1411 ?nomination . ?book rdfs:label "Philip Roth"@en . FILTER(year(?nomination) = 2011) } limit 100
# 208
# SELECT ?deathplace WHERE { ?gediminas Q184711 ?twin_town . ?gediminas Q18658526 ?deathplace . FILTER(CONTAINS(?twin_town, 'Irkutsk')) } limit 100
# Request failed with status code 400
# Failed query number 208
# 209
# SELECT ?fuel_system WHERE { wd:Q12725 wdt:Q1786017 ?fuel_system . FILTER(LANG(?fuel_system) = 'en') } limit 100
# 210
# SELECT ?nominationLabel WHERE { wd:Q903494 wdt:P4353 ?nomination . ?nomination wdt:P4353Person wd:Q212026 . ?nomination wdt:P166 ?award . ?award rdfs:label ?awardLabel . FILTER(LANG(?awardLabel) = 'en') } limit 100
# 211
# SELECT ?interface_standard WHERE { ?interface_standard wdt: ?interface_standard_name . FILTER(CONTAINS(LCASE(?interface_standard_name), 'virtuallink')) } limit 100
# 212
# SELECT ?compArt_person_id WHERE { ?person wdt:P4772 ?compArt_person_id . ?person rdfs:label "Ferenc Molnar"@en . } limit 100
# 213
# SELECT ?id WHERE { ?item wdt:p-31 wd:q-548284 . ?item wdt:p-1416 ?id . FILTER(LANG(?id) = 'es') } limit 100
# 214
# SELECT ?specialty WHERE { ?specialty wdt:P31 wd:Q16647973 . ?specialty rdfs:label ?label . FILTER(CONTAINS(LCASE(?label), 'trichology')) } limit 100
# 215
# SELECT (COUNT(?performance) as ?count) WHERE { ?performance wdt:P175 wd:Q5928 } limit 100
# 216
# SELECT ?state WHERE { ?state wdt:Q21503252 wd:Q1340361 . ?state Q18127 ?label . FILTER(lang(?label) = 'en' && regex(?label, 'Uttarakhand', 'i')) } limit 100
# Request failed with status code 400
# Failed query number 216
# 217
# SELECT ?player WHERE { ?player wdt:P647 wd:Q131371 } limit 100
# 218
# SELECT ?settlementLabel WHERE { ?settlement wdt:P281 'DA' . ?settlement wdt:P31 wd:Q486972 . SERVICE wikibase:label { Q4837690:Q50892604 wikibase:language 'en' . } } limit 100
# Request failed with status code 400
# Failed query number 218
# 219
# SELECT ?result WHERE { wd:Q22964457 wdt:P1873 ?max_players . FILTER(?max_players = 0.0) BIND(xsd:boolean(?max_players = 0.0) as ?result) } limit 100
# 220
# SELECT ?conceptLabel WHERE { ?concept wdt:P279* Q9089 . ?concept Q18127 ?conceptLabel . FILTER(lang(?conceptLabel) = 'en') FILTER(CONTAINS(LCASE(?conceptLabel), 'yatra')) } limit 100
# Request failed with status code 400
# Failed query number 220
# 221
# SELECT ?golf_course WHERE { ?golf_course Q5322166 Q22686 . ?golf_course Q1724915 Q1048525 . ?golf_course Q96775080 ?arena . ?arena Q1724915 Q1076486 . ?arena Q96775080 ?design . ?design Q1724915 Q181156 } limit 100
# Request failed with status code 400
# Failed query number 221
# 222
#  limit 100
# Request failed with status code 400
# Failed query number 222
# 223
# SELECT ?Q28295582 WHERE { ?Q7569 wdt:P22 wd:Q14974 . ?Q7569 wdt:P140 ?Q28295582 . } limit 100
# 224
# SELECT ?population WHERE { wd:Q826 wdt:P1082 ?population_statement . ?population_statement ps:P585 ?time . FILTER(YEAR(?time) = 1967) } limit 100
# 225
# SELECT ?year WHERE { wd:Q4724 wdt:P166 ?award . ?award wdt:P2517 wd:Q4724 . ?award wdt:P166 ?year . ?award wdt: ?award_name . FILTER(CONTAINS(LCASE(?award_name), 'frank p. brown medal')) } limit 100
# 226
# SELECT ?city WHERE { wd:Q340 wdt:Q237/wdt:Q22808403* ?province . ?city wdt:Q22808403 ?province . ?city wdt:P31 wd:Q515 } limit 100
# 227
# SELECT ?successorLabel WHERE { wd:Q15840785 wdt:P1366 ?successor . ?successor rdfs:label ?successorLabel . FILTER(LANG(?successorLabel) = 'en') } limit 100
# 228
# SELECT ?result WHERE { wd:Q652252 wdt:P3738 ?sensitivity . FILTER(?sensitivity = 320) BIND(xsd:boolean(?sensitivity = 320) as ?result) } limit 100
# 229
# SELECT ?used_metre WHERE { wd:Q8275 wdt:P2551 ?used_metre . } limit 100
# 230
# SELECT ?harbourLabel ?locationLabel WHERE { ?harbour wdt:P974 wd:Q1633893 . ?harbour wdt:P625 ?location . ?location rdfs:label ?locationLabel . FILTER(LANG(?locationLabel) = 'en') ?harbour rdfs:label ?harbourLabel . FILTER(LANG(?harbourLabel) = 'en' && CONTAINS(?harbourLabel, 'on harbour') && CONTAINS(?harbourLabel, 'Kryvyi Rih')) } limit 100
# 231
# SELECT ?actor WHERE { ?production wdt:P161 wd:Q42421333 ; wdt:P161 ?actor . } limit 100
# 232
# SELECT ?cause WHERE { ?rain wdt:P1478 ?cause . FILTER(LCASE(STR(?rain)) = LCASE(STR("rain"@en))) } limit 100
# 233
# SELECT ?service_branch WHERE { ?service_branch wdt:P112 Q769097 . ?service_branch wdt:P112 Q769097 . ?service_branch wdt:P355 Q216344 } limit 100
# Request failed with status code 400
# Failed query number 233
# 234
# SELECT ?result WHERE { wd:Q206181 wdt:P136 ?genre . FILTER(?genre IN (wd:Q203720, wd:Q1627155)) BIND(xsd:boolean(?genre IN (wd:Q203720, wd:Q1627155)) as ?result) } limit 100
# 235
# SELECT ?date WHERE { ?film wdt:P166 Q17500591 . ?film wdt:P2521 Q96474691 . ?film wdt:Q3297652 ?actor . ?actor rdfs:label "Aaron Kwok"@en . ?film wdt:Q186408 ?date . } limit 100
# Request failed with status code 400
# Failed query number 235
# 236
# SELECT ?date WHERE { ?marriage_event wdt:P26 wd:Q6101 ; wdt:P813 ?date . ?marriage_event wdt:P451 wd:Q3713678 . } limit 100
# 237
# SELECT ?spouse WHERE { wd:Q19673 wdt:P26 ?spouse_statement . ?spouse_statement ps:P26 ?spouse . ?spouse_statement pq:P580 ?start_date . FILTER(?start_date >= "1970-01-01T00:00:00Z"^^xsd:dateTime) } limit 100
# 238
# SELECT ?appearance WHERE { ?christmas_tree wdt:P4584 ?appearance . ?appearance Q186408 ?date . FILTER(MONTH(?date) = 1 && DAY(?date) = 19) } limit 100
# Request failed with status code 400
# Failed query number 238
# 239
# SELECT ?venueLabel WHERE { wd:Q213837 wdt:P115 ?venue . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# 240
# SELECT ?Q6881511 WHERE { ?parent wdt:P355 wd:Q19839066 . ?Q6881511 wdt:P749 ?parent . } limit 100
# 241
# SELECT ?person WHERE { ?person wdt:P8403 ?theory . ?person wdt:P734 'Halley' . FILTER(CONTAINS(LCASE(?theory), 'proper motion')) } limit 100
# 242
# SELECT ?head_coach WHERE { wd:Q213417 wdt:P286 ?head_coach . ?head_coach rdfs:label ?label . FILTER(LCASE(?label) = LCASE('<<HEAD_COACH_NAME>>')) } limit 100
# 243
# SELECT ?national_cuisine WHERE { ?national_cuisine Q350895 Q1778821 . FILTER(REGEX(STR(?national_cuisine), '^M', 'i')) } limit 100
# Request failed with status code 400
# Failed query number 243
# 244
# SELECT ?series WHERE { ?series rdf:type Q5398426 . ?series Q18127 ?label . FILTER(CONTAINS(LCASE(?label), 'zigby')) } limit 100
# Request failed with status code 400
# Failed query number 244
# 245
# SELECT ?spouse ?start_time WHERE { wd:Q231417 wdt:P26 ?spouse_statement . ?spouse_statement ps:P26 ?spouse . OPTIONAL { ?spouse_statement pq:P580 ?start_time } } limit 100
# 246
# SELECT ?language WHERE { ?person rdfs:label "Peter Faber"@en . ?person wdt:P1251 ?language . ?person wdt:p-RegulatoryBody wd:Q48509 . } limit 100
# 247
# SELECT ?honorary_title WHERE { ?albert_gunther wdt:P166 ?honorary_title . ?p_a_buxton wdt:P166 ?honorary_title . FILTER(?albert_gunther = Q57514) FILTER(?p_a_buxton = Q15994338) } limit 100
# Request failed with status code 400
# Failed query number 247
# 248
# SELECT ?result WHERE { wd:Q12046224 wdt:P2659 ?topographic_isolation . FILTER(?topographic_isolation = 0.7) BIND(xsd:boolean(?topographic_isolation = 0.7) as ?result) } limit 100
# 249
# SELECT ?awardLabel WHERE { wd:Q312585 wdt:P166 ?award . ?award wdt:P9955 ?date . FILTER(?date = '2004-01-01T00:00:00Z'^^xsd:dateTime) SERVICE wikibase:label { bd:serviceParam wikibase:language 'en' . } } limit 100
# 250
# SELECT ?location WHERE { ?google wdt:P159 ?headquarters . ?headquarters wdt:P625 ?location . ?formation wdt:P355 ?google . ?formation wdt:P625 ?formation_location . FILTER(CONTAINS(LCASE(?formation_locationLabel), LCASE('formation of google'))) } limit 100
# 251
# SELECT ?melody WHERE { wd:Q1324254 wdt:P1625 ?melody . } limit 100
# 252
# SELECT ?end_time WHERE { ?event wdt:P131 ?borough . ?event wdt:P582 ?end_time . FILTER(?borough = wd:Q184) } limit 100
# 253
# SELECT ?result WHERE { ?item wdt:P1096 0.0567 . ?item wdt:P376 wd:Q782867 . BIND(?item as ?result) } limit 100
# 254
# SELECT ?relation WHERE { ?basinCountry wdt:P206 ?lake . ?basinCountry wdt:P530 ?relation . FILTER(?lake = wd:Q202905) } limit 100
# 255
# SELECT ?city WHERE { ?org wdt: ?city . ?org rdfs:label "Financial Times"@en . } LIMIT 2
# 256
# SELECT (COUNT(?active_ingredient) as ?count) WHERE { wd:Q216935 wdt:P3781 ?active_ingredient . } limit 100
# 257
# SELECT ?place_of_burial WHERE { wd:Q53437 wdt:P119 ?place_of_burial . } limit 100
# 258
# SELECT ?result WHERE { wd:Q141634 wdt:P2233 ?semi_major_axis . FILTER(?semi_major_axis > 2.2361778) BIND(xsd:boolean(?semi_major_axis > 2.2361778) as ?result) } limit 100
# 259
# SELECT ?code WHERE { ?Q15284 wdt:P382 ?code . ?Q15284 rdfs:label "Nijmegen"@en . } limit 100
# 260
# SELECT ?result WHERE { wd:Q105875 wdt:P166 ?award . ?award wdt:P166Category wd:Q691203 . ?award wdt:P166Winner wd:Q105875 . BIND(xsd:boolean(true) as ?result) } limit 100
# 261
# SELECT ?total_fertility_rate WHERE { wd:Q1049 p:P2184 ?statement . ?statement ps:P2184 ?total_fertility_rate . ?statement pq:P585 ?estimation_date . FILTER(CONTAINS(LCASE(?estimation_date), 'estimation')) } limit 100
# 262
# SELECT ?result WHERE { wd:Q18844603 p:P2939 ?half_life . ?half_life ps:P2939 ?half_life_value . FILTER(?half_life_value < 0.54) BIND(xsd:boolean(?half_life_value < 0.54) as ?result) } limit 100
# 263
# SELECT ?Q3624078 WHERE { ?pope wdt:P1906 Q237 . ?pope wdt:P1308 ?office_holder . ?office_holder wdt:P1313 ?Q3624078 . } limit 100
# Request failed with status code 400
# Failed query number 263
# 264
# SELECT ?alphabetLabel WHERE { wd:Q18220751 wdt:P527 ?alphabet . ?alphabet rdfs:label ?alphabetLabel . FILTER(LANG(?alphabetLabel) = 'en') } limit 100
# 265
# SELECT ?programming_language WHERE { ?person rdfs:label "Dennis M. Ritchie"@en . ?programming_language wdt:P50 ?person . ?programming_language wdt:P31 wd:Q9143 } limit 100
# 266
# ...
# 414
# SELECT ?language WHERE { ?translation wdt:P629 wd:Q781898 . ?translation wdt:P655 wd:Q1710495 . ?translation wdt:P407 ?language . } limit 100
# 415
# SELECT ?result WHERE { ?castle wdt:P466 ?result . ?castle rdfs:label "Windsor Castle"@en . ?person wdt:p-Occupation wd:Q{Q62439078} . ?person rdfs:label ?person_label . ?person wdt:p-employer ?castle . ?person_label bif:contains '"{tenant}"' . } limit 100
# Request failed with status code 400
# Failed query number 415
# 416
# SELECT ?end_date WHERE { ?Q84232 ?Q28268345 ?Q518244 . ?Q518244 ?Q24575125 ?end_date . FILTER(datatype(?end_date) = xsd:dateTime) } limit 100
# 417
# SELECT ?series_ordinal WHERE { ?ether wdt:P2260 9.53 . ?ether wdt:P1545 ?series_ordinal . } limit 100
# 418
# SELECT ?result WHERE { wd:Q133871 wdt:P735 ?name . FILTER(lcase(?name) = lcase('normal distribution')) wd:Q133871 wdt:P61 ?discoverer . FILTER(lcase(?discoverer) = lcase('Bernhard Riemann')) BIND(xsd:boolean(lcase(?discoverer) = lcase('Bernhard Riemann')) as ?result) } limit 100
# 419
# SELECT ?result WHERE { wd:Q151503 wdt:P2243 ?apoapsis . FILTER(?apoapsis = 2.126) BIND(xsd:boolean(?apoapsis = 2.126) as ?result) } limit 100
# 420
# SELECT ?bourbon ?abv WHERE { ?bourbon wdt:P31 wd:Q1317341 . ?bourbon wdt:P495 wd:Q30 . ?bourbon wdt:P1628 ?abv . FILTER(lang(?abv) = 'en') . FILTER(?abv > 0) . FILTER NOT EXISTS { ?bourbon wdt:P31 wd:Q2814 } } ORDER BY ?abv LIMIT 1
# 421
# SELECT ?genetic_association WHERE { ?Q12136 wdt:P2176 ?genetic_association . ?Q12136 rdfs:label 'major depressive disorder'@en . ?genetic_association Q56229865 Q81459790 . ?genetic_association Q56229865 ?determination_method . ?determination_method rdfs:label 'TAS'@en . } limit 100
# Request failed with status code 400
# Failed query number 421
# 422
# SELECT ?end_date WHERE { wd:Q247318 p:P582 ?end_time . ?end_time ps:P582 ?end_date . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# 423
# SELECT ?book_series WHERE { ?book wdt:P50 wd:Q1067 . ?book wdt:P136 ?book_series . } limit 100
# 424
# SELECT ?biogeochemical_cycle WHERE { ?biogeochemical_cycle rdfs:label ?label . FILTER(CONTAINS(LCASE(?label), 'cycle') && CONTAINS(LCASE(?label), 'biogeochemical')) } limit 100
# Request failed with status code 500
# Failed query number 424
# 425
# SELECT ?item WHERE { wd:Q355 ?item ?statement . FILTER(CONTAINS(LCASE(STR(?item)), 'business') || CONTAINS(LCASE(STR(?item)), 'product') || CONTAINS(LCASE(STR(?item)), 'material')) } limit 100
# 426
# SELECT ?footclub WHERE { ?footclub Q18127 ?label . FILTER(STRSTARTS(LCASE(?label), 'w') && LANG(?label) = 'en') } limit 100
# Request failed with status code 400
# Failed query number 426
# 427
# SELECT (COUNT(?translation) as ?count) WHERE { wd:Q26833 wdt:P747 ?edition . ?edition wdt:P629 ?translation } limit 100
# 428
# SELECT ?result WHERE { ?protein wdt:P688 ?gene . ?gene wdt:P703 ?species . ?protein wdt:P6800 ?sequence . FILTER(CONTAINS(?sequence, 'ipg2828')) ?protein wdt:P1542 ?result . } limit 100
# 429
# SELECT ?education ?expertise WHERE { wd:Q9106 wdt:P69 ?education . wd:Q9106 wdt:P2650 ?expertise . } limit 100
# 430
# SELECT ?team WHERE { ?player rdfs:label 'Peter Schmeichel'@en . ?player wdt:P54 ?team . ?player wdt:P2031 ?start . FILTER(YEAR(?start) = 1984) } limit 100
# 431
# SELECT ?continent_name WHERE { wd:Q6920087 wdt:P4552 ?mountain_range . ?mountain_range wdt:p-locatedIn ?continent . ?continent rdfs:label ?continent_name . FILTER(LANG(?continent_name) = 'en') } limit 100
# 432
# SELECT ?result WHERE { wd:Q994867 wdt:P3842 ?entity . ?entity rdfs:label ?label . FILTER(LCASE(?label) = LCASE('Mexico City')) BIND(xsd:boolean(?label = 'Mexico City') as ?result) } limit 100
# 433
# SELECT ?grant WHERE { ?grant wdt: Q191701 . ?grant wdt:P1711 ?institution . ?institution wdt:p-instanceOf Q4671277 . } limit 100
# Request failed with status code 400
# Failed query number 433
# 434
# SELECT ?country WHERE { ?tyumen Q22808403 ?country . ?tyumen Q3406134 ?inception . FILTER(?inception <= "1991-12-27"^^xsd:dateTime) } limit 100
# Request failed with status code 400
# Failed query number 434
# 435
# SELECT ?regulator WHERE { ?regulator wdt:P128 Q27593301 . } limit 100
# Request failed with status code 400
# Failed query number 435
# 436
# SELECT ?result WHERE { wd:Q57051271 wdt:P5520 ?toughness . FILTER(?toughness < 7.2) BIND(xsd:boolean(?toughness < 7.2) as ?result) } limit 100
# 437
# SELECT ?advisorLabel WHERE { wd:Q220008 wdt:P737/wdt:P184 ?advisor . SERVICE wikibase:label { bd:serviceParam wikibase:language 'en' . ?advisor rdfs:label ?advisorLabel } } limit 100
# 438
# SELECT ?unit WHERE { ?unit wdt:P31 Q11723795 . ?unit rdfs:label ?label . FILTER(lang(?label) = 'en' && STRSTARTS(LCASE(?label), 'p') && REGEX(?label, 'temperature', 'i')) } LIMIT 1
# Request failed with status code 400
# Failed query number 438
# 439
# SELECT ?temperature WHERE { ?toxaphene Q1048589 '1.65' . ?toxaphene Q11579 ?temperature . } limit 100
# Request failed with status code 400
# Failed query number 439
# 440
# SELECT ?name WHERE { ?Q223677 rdfs:label "John Foster Dulles"@en . ?Q223677 wdt:P4187 ?script . ?script wdt:P898 ?alphabet . ?script rdfs:label ?name . } limit 100
# 441
# SELECT ?result WHERE { wd:Q56005 wdt:P40 wd:Q21066699 . wd:Q56005 wdt:P40 wd:Q452925 . BIND(xsd:boolean(EXISTS { wd:Q56005 wdt:P40 wd:Q21066699 . wd:Q56005 wdt:P40 wd:Q452925 . }) AS ?result) } limit 100
# 442
# SELECT Q26839968 WHERE { ?person Q75232720 wd:Q22686 . ?person Q30041909 Q26839968 . Q26839968 Q21503252 wd:Q51637 . } limit 100
# Request failed with status code 400
# Failed query number 442
# 443
# SELECT ?unit WHERE { ?density_unit wdt:P881 wd:Q1077158 . ?density_unit rdfs:label ?unit . FILTER(LANG(?unit) = 'en') } limit 100
# 444
# SELECT ?point_in_time WHERE { wd:Q75655 p:P69 ?degree_statement . ?degree_statement ps:P69 wd:Q798137 . ?degree_statement pq:P585 ?point_in_time . } limit 100
# 445
# SELECT ?anatomical_location WHERE { ?place wdt:P1552 wd:Q2363308 . ?place wdt: ?anatomical_location . } limit 100
# 446
# SELECT Q3346693 WHERE { Q3346693 Q5153528 Q207391 . Q3346693 Q21503252 Q194015 } limit 100
# Request failed with status code 400
# Failed query number 446
# 447
# SELECT ?date WHERE { wd:Q80976 wdt:P94 ?coat_of_arms . ?coat_of_arms wdt:P18 ?image . ?image wdt:Q3406134 ?date . FILTER(?date >= "1947-01-01T00:00:00Z"^^xsd:dateTime && ?date <= "1949-12-31T23:59:59Z"^^xsd:dateTime) } limit 100
# 448
# SELECT ?person WHERE { ?film wdt:P31 Q11424 . ?film wdt:P1411 ?nomination . ?nomination wdt:P805 Q172582 . ?nomination wdt:P57 ?person . ?nomination wdt:P165 ?award . FILTER(CONTAINS(LCASE(?awardLabel), 'best sound mixing')) FILTER(CONTAINS(LCASE(?filmLabel), 'gladiator')) } limit 100
# Request failed with status code 400
# Failed query number 448
# 449
# SELECT ?team WHERE { ?team wdt:Q21503252 wd:Q1194951 . ?team Q18127 ?label . FILTER(lang(?label) = 'en') . FILTER(STRSTARTS(LCASE(?label), 't')) } limit 100
# Request failed with status code 400
# Failed query number 449
# 450
# SELECT ?childLabel WHERE { wd:Q2349136 wdt:P3373 ?sibling . ?sibling wdt:P40 ?child . ?child rdfs:label ?childLabel . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" } } limit 100
# 451
# SELECT ?role WHERE { wd:Q11881 p:P39 ?statement . ?statement ps:P39 ?position . ?position rdfs:label ?role . FILTER(CONTAINS(LCASE(?role), LCASE("replaced")) && CONTAINS(LCASE(?role), LCASE("William Henry Harrison"))) } limit 100
# 452
# SELECT ?fifa_player_id WHERE { ?player wdt:P1469 ?fifa_player_id . ?player rdfs:label "Stanislav Cherchesov"@en . } limit 100
# 453
# SELECT ?result WHERE { wd:Q294192 wdt:p-followed_by ?followed_by . ?followed_by wdt:p-follows wd:Q294192 . wd:Q294192 wdt:p-{{P97}} wd:Q693614 . ?followed_by rdfs:label ?result . FILTER(LANG(?result) = "en") } limit 100
# Request failed with status code 400
# Failed query number 453
# 454
# SELECT ?eraLabel WHERE { wd:Q190436 wdt:P2348 ?era . ?era wdt:P582 ?end . FILTER(?end <= "600-01-01T00:00:00Z"^^xsd:dateTime) SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } } limit 100
# 455
# SELECT ?rankLabel WHERE { wd:Q432637 p:P410 ?militaryRankStatement . ?militaryRankStatement ps:P410 ?rank . ?militaryRankStatement pq:P580 ?startTime . ?startTime wikibase:timePrecision ?precision . FILTER(?precision <= 9) ?startTime wikibase:timeValue ?startTimeValue . ?militaryRankStatement pq:P582 ?endTime . ?endTime wikibase:timePrecision ?precision2 . FILTER(?precision2 <= 9) ?endTime wikibase:timeValue ?endTimeValue . FILTER(?startTimeValue >= "1774-01-01T00:00:00Z"^^xsd:dateTime && ?endTimeValue <= "1796-12-31T23:59:59Z"^^xsd:dateTime) SERVICE wikibase:label { bd:serviceParam wikibase:language "en". ?rank rdfs:label ?rankLabel. } } limit 100
# 456
# SELECT ?nominationLabel WHERE { wd:Q28470 wdt:P1411 ?nomination . ?nomination wdt:P166 ?award . FILTER(CONTAINS(STR(?award), '12th Academy Awards')) SERVICE wikibase:label { bd:serviceParam wikibase:language 'en' . } } limit 100
# 457
# SELECT ?crossref_funder_id WHERE { ?Q148584 wdt:P3153 ?crossref_funder_id . FILTER(REGEX(STR(?Q148584Label), 'National Museum of American History', 'i')) } limit 100
# 458
# SELECT ?siruta_code WHERE { ?Q79808 wdt:P843 ?siruta_code . FILTER(LCASE(STR(?Q79808)) = LCASE('Constanta')) } limit 100
# 459
# SELECT ?brockhaus_id WHERE { ?Q298 wdt:P5019 ?brockhaus_id . ?Q298 rdfs:label 'Chile'@en . } limit 100
# 460
# SELECT ?cityLabel WHERE { ?city Q21503252 Q515 . ?city Q18127 ?cityLabel . FILTER(Q1860(?cityLabel) = 'en') FILTER(CONTAINS(Q8185162(?cityLabel), 'worms')) ?city Q22808403 Q6837 . } limit 100
# Request failed with status code 400
# Failed query number 460
# 461
# SELECT ?date WHERE { ?person wdt:P26 wd:Q46109451 . ?person wdt:P735 'Roman Abramovich' . ?person wdt:P2842 ?marriage . ?marriage wdt:P813 ?date . } limit 100
# 462
# SELECT ?result WHERE { wd:Q190230 wdt:P2661 ?target_interest_rate . FILTER(?target_interest_rate = 5.25) BIND(xsd:boolean(?target_interest_rate = 5.25) as ?result) } limit 100
# 463
# SELECT ?result WHERE { wd:Q19190 wdt:P106 ?occupation . FILTER(?occupation IN (wd:Q33999, wd:Q970153)) BIND(xsd:boolean(?occupation IN (wd:Q33999, wd:Q970153)) as ?result) } limit 100
# 464
# SELECT ?result WHERE { wd:Q163286 ?relatives ?person . ?person rdfs:label "Rick Cosnett"@en . BIND(xsd:boolean(?relatives != wd:Q0) as ?result) } limit 100
# 465
# SELECT ?item WHERE { ?item wdt:P248 wd:Q1085823 } limit 100
# 466
# SELECT ?id WHERE { ?person wdt:P4368 ?id . ?person rdfs:label "Brett Favre"@en . } limit 100
# 467
# SELECT ?area_of_workLabel WHERE { wd:Q28792298 wdt:P101 ?area_of_work . SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } } limit 100
# 468
# SELECT ?gcatholic_id WHERE { wd:Q84090 wdt:P2971 ?gcatholic_id . } limit 100
# 469
# SELECT ?team (COUNT(?match) AS ?num_matches) WHERE { ?player rdfs:label "Roger Milla"@en . ?player wdt:P54 ?team . ?player wdt:P1350 ?match . } GROUP BY ?team limit 100
# 470
# SELECT ?end_date WHERE { ?marriage wdt:P26 Q4616 ; wdt:P26 Q57846887 ; wdt:P582 ?end_date . } limit 100
# Request failed with status code 400
# Failed query number 470
# 471
# SELECT ?kinopoisk_id WHERE { ?person wdt:P2604 ?kinopoisk_id . ?person rdfs:label "Stanley Donen"@en . } limit 100
# 472
# SELECT ?diseaseLabel WHERE { ?disease wdt:P31 Q12136 . ?disease rdfs:label ?diseaseLabel . FILTER(lang(?diseaseLabel) = 'en' && STRSTARTS(LCASE(?diseaseLabel), 'y')) } LIMIT 1
# Request failed with status code 400
# Failed query number 472
# 473
# SELECT ?result WHERE { ?item wdt:P3018 wd:Q128011 . ?item wdt:P3018Continent wd:Q49 . ?item wdt:P821 ?result } limit 100
# 474
# SELECT ?orderLabel WHERE { wd:Q44281 wdt:P140 ?order . ?order rdfs:label ?orderLabel . FILTER(LANG(?orderLabel) = 'en') } limit 100
# 475
# SELECT ?productLabel WHERE { ?product wdt:P31 wd:Q40231 . ?product wdt:P279* Q542929 . ?product wdt:P366 ?papermaking . ?papermaking wdt:P279* Q335415 . ?product wdt:P186 ?bleach . ?bleach wdt:P279* Q904 . SERVICE wikibase:label { bd:serviceParam wikibase:language "en". ?product rdfs:label ?productLabel. } } limit 100
# Request failed with status code 400
# Failed query number 475
# 476
# SELECT ?event WHERE { ?ship rdfs:label "SS Naronic"@en . ?ship wdt:P793 ?event . } limit 100
# 477
# SELECT ?result WHERE { wd:Q299595 p:Q_ID ?org . ?org p:Q_ID ?position . ?position rdfs:label "chairwoman"@en . ?position wdt:P108 ?working_for . ?working_for rdfs:label "working for"@en . } limit 100
# 478
# SELECT ?student WHERE { ?student wdt:P184 wd:Q200101 . } limit 100
# 479
# SELECT ?location WHERE { wd:Q18118720 wdt:P190 wd:Q2680952 . wd:Q18118720 wdt:P291 ?location . } limit 100
# 480
# SELECT Q82794 WHERE { ?region wdt:P276 wd:Q1197 . ?region wdt:P2547 ?coastline . ?coastline rdfs:label "coast of Lower Saxony"@en . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" } } limit 100
# Request failed with status code 400
# Failed query number 480
# 481
# SELECT (COUNT(Q5113984) as Q3519259) WHERE { ?Q210402 Q212980 Q5113984 . Q5113984 Q21503252 Q5113984 . } limit 100
# Request failed with status code 400
# Failed query number 481
# 482
# SELECT ?result WHERE { ?city wdt: ?population . ?city wdt:P17 wd:Q1227 . ?city wdt:P131 true . BIND(xsd:boolean(?population > 0) as ?result) } limit 100
# 483
# SELECT ?position WHERE { ?person1 p:replaces wd:Q1700617 . ?person2 p:replacedBy ?person1 . ?person2 wdt:P413 ?position . ?person2 rdfs:label "William Carmichael"@en . } limit 100
# 484
# SELECT ?food_or_dish WHERE { ?food_or_dish rdfs:label ?label . FILTER(lang(?label) = 'en') FILTER(CONTAINS(LCASE(?label), 'torta')) ?food_or_dish wdt:P31/wdt:Q61268336* wd:Q2095 } limit 100
# 485
# SELECT ?particle_type WHERE { ?particle wdt:P2222 ?gyromagnetic_ratio . ?particle wdt:P31 ?particle_type . FILTER(?gyromagnetic_ratio = (SELECT MAX(?gyro) WHERE { ?p wdt:P2222 ?gyro . })) } limit 100
# Request failed with status code 400
# Failed query number 485
# 486
# SELECT ?genreLabel WHERE { ?genre Q1047337 Q223393 . ?genre rdfs:label ?genreLabel . FILTER(CONTAINS(LCASE(?genreLabel), 'vita') && LANG(?genreLabel) = 'en') } limit 100
# Request failed with status code 400
# Failed query number 486
# 487
# SELECT ?equation WHERE { ?horsepower_unit wdt:P366 ?usage . ?usage wdt:P2534 ?equation . FILTER(CONTAINS(LCASE(?equation), LCASE("horsepower"))) } limit 100
# 488
# SELECT ?parent_company WHERE { ?person wdt:P1416 wd:Q258385 . ?person wdt:P749 ?parent_company . } limit 100
# 489
# SELECT ?languageLabel WHERE { wd:Q17872 wdt:P1705 ?language . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# 490
# SELECT ?text_input WHERE { wd:Q108585133 wdt:Q29654788 ?emoji . ?emoji wdt:Q8819 ?text_input . FILTER(lang(?text_input) = 'en') } limit 100
# 491
# SELECT ?languageLabel WHERE { wd:Q158772 wdt:P103 ?language . SERVICE wikibase:label { bd:serviceParam wikibase:language 'en' . } } limit 100
# 492
# SELECT ?personLabel WHERE { ?person wdt:P31 wd:Q5 . ?person wdt:P108 wd:Q371712 . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" } } LIMIT 1
# 493
# SELECT ?composition WHERE { ?composer rdfs:label "Dionysus"@en . ?composition wdt:P86 ?composer . } limit 100
# 494
# SELECT ?description WHERE { ?Q39503 rdfs:label 'Artemis'@en . ?Q39503 schema:description ?description . FILTER(LANG(?description) = 'en') } limit 100
# 495
# SELECT ?position WHERE { wd:Q56854980 wdt:P413 ?position . FILTER NOT EXISTS { wd:Q167561 wdt:P413 ?position } } limit 100
# 496
#  limit 100
# Request failed with status code 400
# Failed query number 496
# 497
# SELECT ?award WHERE { ?album wdt:P31 wd:Q482994 . ?album rdfs:label "Cream"@en . ?album wdt:P571 ?date . FILTER(?date >= "1983-0-0"^^xsd:dateTime) ?album wdt:P166 ?award . ?award rdfs:label "p-{award_won}"@en . } limit 100
# 498
# SELECT ?result WHERE { ?place wdt:P625 ?coordinates . ?place wdt:P1344 wd:Q162362 . FILTER(?coordinates > ?Q58192337) BIND(xsd:boolean(?coordinates > ?Q58192337) as ?result) } limit 100
# 499
# SELECT ?positionLabel WHERE { ?person rdfs:label "Jacinda Ardern"@en . ?person wdt:P413 ?position . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } } limit 100
# CPU times: user 12 s, sys: 1.85 s, total: 13.8 s
# Wall time: 23min 34s

# %%
len(v)
# Out:
# 500

# %%
v_df = pd.DataFrame(v)

# %%
len(v_df[v_df[0] == 'Pass'])
# Out:
# 384

# %%
q = 'SELECT ?facilityLabel WHERE { ?defensive_wall wdt:P846 ?facility . SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . } }'

# %%
v_df
# Out:
#         0  1
# 0    Pass  0
# 1    Pass  0
# 2    Pass  0
# 3    Fail  0
# 4    Pass  0
# ..    ... ..
# 495  Pass  0
# 496  Fail  0
# 497  Pass  0
# 498  Pass  0
# 499  Pass  0
#
# [500 rows x 2 columns]

# %%
translator("What is the product with the lowest consumption rate per capita whose has part is paraffin wax?")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 translator("What is the product with the lowest consumption rate per capita whose has part is paraffin wax?")
#
# Cell In[18], line 7, in translator(question)
#       5 except Exception:
#       6     query_template = ""
# ----> 7 query = resolve_query_template(query_template)
#       8 return query
#
# Cell In[16], line 2, in resolve_query_template(t)
#       1 def resolve_query_template(t):
# ----> 2     vocab_items = [(v["item_tag"], v["item_label_quesses"]) for v in t["vocabulary"]]
#       3     resolved_vocabulary = {item_tag: vocab_lookup(item_label_quesses[0], item_tag=item_tag) for item_tag, item_label_quesses in vocab_items}
#       4     query = t['query_template']
#
# TypeError: string indices must be integers

# %%
question = "What is the product with the lowest consumption rate per capita whose has part is paraffin wax?"

# %%
question = """
When did James Thomas Farrell receive the St. Louis Literary Award?",
"""

# %%
query_template_json = chain.run(question)
print(query_template_json)
# Out:
# {
#   "query_template": "SELECT ?date WHERE { wd:q-JamesThomasFarrell wdt:p-Award ?award . ?award wdt:p-AwardReceivedDate ?date . ?award wdt:p-AwardReceived ?received . ?received rdfs:label \"St. Louis Literary Award\"@en }",
#   "vocabulary": [
#     {
#       "item_tag": "q-JamesThomasFarrell",
#       "item_label_quesses": ["James Thomas Farrell", "Farrell, James Thomas"]
#     },
#     {
#       "item_tag": "p-Award",
#       "item_label_quesses": ["Award", "Prize", "Honour"]
#     },
#     {
#       "item_tag": "p-AwardReceivedDate",
#       "item_label_quesses": ["Award received date", "Date of receiving award", "Date received"]
#     },
#     {
#       "item_tag": "p-AwardReceived",
#       "item_label_quesses": ["Award received", "Receiving award", "Award recipient"]
#     }
#   ]
# }

# %%
query_template = json.loads(query_template_json)
resolve_query_template(query_template)
# Out:
# No property found for 'Award received date'
# 'SELECT ?date WHERE { wd:Q1371154 wdt:P166 ?award . ?award wdt: ?date . ?award wdt:P166 ?received . ?received rdfs:label "St. Louis Literary Award"@en }'

# %%
def resolve_query_template(t):
    vocab_items = [(v["item_tag"], v["item_label_quesses"]) for v in t["vocabulary"]]
    vocab_items = sorted(vocab_items, key=lambda x: x[1], reverse=True)
    print(vocab_items)
    resolved_vocabulary = {item_tag: vocab_lookup(item_label_quesses[0], item_tag=item_tag) for item_tag, item_label_quesses in vocab_items}
    print(resolved_vocabulary)
    query = t['query_template']
    for item_tag, item_id in resolved_vocabulary.items():
        query = query.replace(item_tag, item_id)
    result = query
    return result

# %%
query_template['vocabulary']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 query_template['vocabulary']
#
# TypeError: string indices must be integers

# %%
'limit' in q.lower()
# Out:
# False
